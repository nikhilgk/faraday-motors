# %%
import pandas as pd
import scipy as sp
import scipy.spatial as spl
import numpy as np

# %%
ads = pd.read_csv("../data/ad_rates_uniq.csv")
urban = pd.read_csv("../data/initial_data_urban_area.csv")
al = ads.ix[:,['Latitude', 'Longitude']]
ul = urban.ix[:,['Latitude', 'Longitude']]

kdt = spl.cKDTree(al)
# print kdt.query([29.974444,-92.134167], 1)
# print kdt.query([40.804444, -90.401667], 1)
# print kdt.query([29.7513889,-82.425])
# d,i = kdt.query([38.9175,-75.5055556], 4)
d,i = kdt.query(ul, 1)

print d
print i


for row_index, row in urban.iterrows():
    print(row["UANAME"] + " ---" + ads.values[i[row_index], 0])


        
# print(ads.ix[1, ["Market Name"]])
# print(ads.values[1, 1])        
# print ads.ix[i]
# print kdt.query(ul, 1)[1]
# print  ads.ix[kdt.query(ul, 1)[1],['Market Name', 'Latitude', 'Longitude']]
# Out:
# [ 0.27457756  0.79517639  0.67432601 ...,  0.73002232  0.78560549
#   0.46806999]
# [ 93  49 599 ..., 113 113 679]
# Abbeville, LA ---Lafayette LA (CBSA)
# Abbeville, SC ---Augusta (DMA)
# Abbotsford, WI ---Merrill WI (CBSA)
# Aberdeen--Bel Air South--Bel Air North, MD ---Baltimore
# Aberdeen, MS ---Columbus MS (CBSA)
# Aberdeen, SD ---Aberdeen SD (CBSA)
# Aberdeen, WA ---Victoria (DMA)
# Abernathy, TX ---Lubbock (DMA)
# Abilene, KS ---Emporia KS (CBSA)
# Abilene, TX ---Abilene TX (CBSA)
# Abingdon, IL ---Galesburg IL (CBSA)
# Ada, OH ---Findlay OH (CBSA)
# Ada, OK ---Shawnee OK (CBSA)
# Adams, NY ---Watertown-Fort Drum NY (CBSA)
# Adel, GA ---Tallahassee FL (CBSA)
# Adel, IA ---Des Moines
# Adjuntas, PR ---Ponce (Region) (DMA)
# Adrian, MI ---Adrian MI (CBSA)
# Aguadilla--Isabela--San Sebasti�n, PR ---Aguadilla-Isabela PR (CBSA)
# Ahoskie, NC ---Roanoke Rapids NC (CBSA)
# Air Force Academy, CO ---Colorado Springs CO (CBSA)
# Ajo, AZ ---Phoenix
# Akron, NY ---Batavia NY (CBSA)
# Akron, OH ---Cleveland-Akron (Canton) (DMA)
# Alachua, FL ---Gainesville
# Alamogordo, NM ---Alamogordo NM (CBSA)
# Alamosa, CO ---Canon City CO (CBSA)
# Albany--Schenectady, NY ---Albany-Schenectady-Troy (DMA)
# Albany, GA ---Tallahassee FL (CBSA)
# Albany, MN ---St. Cloud MN (CBSA)
# Albany, OR ---Salem OR (CBSA)
# Albemarle, NC ---Rockingham NC (CBSA)
# Albert Lea, MN ---New Ulm MN (CBSA)
# Albertville, AL ---Albertville AL (CBSA)
# Albia, IA ---Kirksville MO (CBSA)
# Albion, MI ---Jackson MI (CBSA)
# Albion, NY ---Batavia NY (CBSA)
# Albion, PA ---Meadville PA (CBSA)
# Albuquerque, NM ---Albuquerque-Santa Fe (DMA)
# Alderson, WV ---Bluefield-Beckley-Oak Hill (DMA)
# Aledo, IL ---Davenport-Rock Island-Moline (DMA)
# Aledo, TX ---Dallas-Fort Worth (DMA)
# Alexander City, AL ---Talladega-Sylacauga AL (CBSA)
# Alexandria, LA ---Alexandria LA (DMA)
# Alexandria, MN ---Alice TX  (CBSA)
# Alfred, NY ---Batavia NY (CBSA)
# Algoma, WI ---Marinette WI-MI (CBSA)
# Algona, IA ---Boone IA (CBSA)
# Alice, TX ---Corpus Christi TX (CBSA)
# Allegan, MI ---Holland MI (CBSA)
# Allendale, SC ---Charlotte-Gastonia-Concord NC-SC (CBSA)
# Allentown, PA--NJ ---East Stroudsburg PA (CBSA)
# Alliance, NE ---Cheyenne-Scottsbluff (DMA)
# Alliance, OH ---Cleveland-Akron (Canton) (DMA)
# Alma--St. Louis, MI ---Alma MI (CBSA)
# Alma, GA ---Tallahassee et al FL-GA (DMA)
# Almont, MI ---Detroit (DMA)
# Alpena, MI ---Bay City MI (CBSA)
# Alpine, TX ---Carlsbad-Artesia NM (CBSA)
# Altavista, VA ---Danville VA (CBSA)
# Alton, IL--MO ---Saint Louis (DMA)
# Altoona, PA ---Amarillo TX  (CBSA)
# Alturas, CA ---Redding CA (CBSA)
# Altus, OK ---Elk City OK (CBSA)
# Alva, OK ---Elk City OK (CBSA)
# Alvarado, TX ---Dallas-Fort Worth (DMA)
# Amarillo, TX ---Ames IA  (CBSA)
# American Falls, ID ---Idaho Falls-Pocatello (DMA)
# Americus, GA ---Warner Robins GA (CBSA)
# Amery, WI ---Menomonie WI (CBSA)
# Ames, IA ---Boone IA (CBSA)
# Amite City, LA ---Hammond LA (CBSA)
# Amory, MS ---Tupelo MS (CBSA)
# Amsterdam, NY ---Albany-Schenectady-Troy (DMA)
# Anaconda-Deer Lodge County, MT ---Butte-Silver Bow MT (CBSA)
# Anacortes, WA ---Washington-Arlington-Alexandria DC-VA-MD-WV (CBSA)
# Anadarko, OK ---Oklahoma City (DMA)
# Anamosa, IA ---Cedar Rapids IA (CBSA)
# Anchorage Northeast, AK ---Victoria (DMA)
# Anchorage, AK ---Victoria (DMA)
# Andalusia, AL ---Troy AL (CBSA)
# Anderson, IN ---New Castle IN (CBSA)
# Anderson, SC ---Brevard NC (CBSA)
# Andrews, SC ---Florence SC (CBSA)
# Andrews, TX ---Hobbs NM (CBSA)
# Angels, CA ---Modesto CA (CBSA)
# Angola, IN ---Angola IN (CBSA)
# Ann Arbor, MI ---Ann Arbor MI (CBSA)
# Anna, IL ---Carbondale IL (CBSA)
# Anna, TX ---Dallas
# Annandale, MN ---St. Cloud MN (CBSA)
# Anniston--Oxford, AL ---Anniston-Oxford AL (CBSA)
# Antigo, WI ---Wausau WI (CBSA)
# Antioch, CA ---Sacramento
# Apalachicola, FL ---Panama City-Lynn Haven FL (CBSA)
# Apple Valley, OH ---Youngstown-Warren-Boardman OH-PA (CBSA)
# Appleton, WI ---Appleton WI (CBSA)
# Arab, AL ---Albertville AL (CBSA)
# Arbuckle, CA ---Clearlake CA (CBSA)
# Arcade, NY ---Batavia NY (CBSA)
# Arcadia--Southeast Arcadia, FL ---Arcadia FL (CBSA)
# Arcadia, LA ---El Dorado AR (CBSA)
# Arcadia, WI ---La Crosse-Eau Claire (DMA)
# Arcata-McKinleyville, CA ---Redding CA (CBSA)
# Archbold, OH ---Adrian MI (CBSA)
# Archer Lodge--Clayton, NC ---Raleigh-Durham (Fayetteville) (DMA)
# Arcola, IL ---Charleston-Mattoon IL (CBSA)
# Ardmore, OK ---Shawnee OK (CBSA)
# Arecibo, PR ---Arecibo (Region) (DMA)
# Arizona City, AZ ---Phoenix
# Arkadelphia, AR ---Hot Springs AR (CBSA)
# Arkansas City, KS ---Wichita KS (CBSA)
# Arlington, TN ---Memphis
# Arroyo Grande--Grover Beach, CA ---Hanford-Corcoran CA (CBSA)
# Artesia, NM ---Carlsbad-Artesia NM (CBSA)
# Arvin, CA ---Bakersfield CA (CBSA)
# Ashburn, GA ---Tallahassee et al FL-GA (DMA)
# Ashdown, AR ---Marshalltown IA  (CBSA)
# Asheboro, NC ---Greensboro-High Point NC (CBSA)
# Asheville, NC ---Asheville NC (CBSA)
# Ashland City, TN ---Nashville (DMA)
# Ashland, MO ---Jefferson City MO (CBSA)
# Ashland, NE ---Fremont NE (CBSA)
# Ashland, OH ---Mansfield OH (CBSA)
# Ashland, PA ---Bloomsburg-Berwick PA (CBSA)
# Ashland, WI ---Duluth MN-WI (CBSA)
# Ashtabula, OH ---Ashtabula OH (CBSA)
# Ashville, OH ---Columbus-Tupelo-West Point (DMA)
# Aspen, CO ---Canon City CO (CBSA)
# Astoria, OR ---Portland OR (DMA)
# Atchison, KS--MO ---Atchison KS (CBSA)
# Athens-Clarke County, GA ---Jefferson GA (CBSA)
# Athens, AL ---Huntsville-Decatur (Florence) (DMA)
# Athens, OH ---Athens OH (CBSA)
# Athens, TN ---Athens TN (CBSA)
# Athens, TX ---Athens-Clarke County GA  (CBSA)
# Athol, MA ---Springfield-Holyoke (DMA)
# Atlanta, GA ---Atlanta (DMA)
# Atlanta, TX ---Marshalltown IA  (CBSA)
# Atlantic City, NJ ---Allentown-Bethlehem-Easton PA-NJ (CBSA)
# Atlantic, IA ---Ontario OR-ID  (CBSA)
# Atmore, AL ---Daphne-Fairhope AL (CBSA)
# Atoka, TN ---Memphis
# Attica, IN ---Lafayette IN (DMA)
# Attica, NY ---Batavia NY (CBSA)
# Au Sable, MI ---Bay City MI (CBSA)
# Aubrey, TX ---Dallas
# Auburn--North Auburn, CA ---Sacramento
# Auburn, AL ---Auburn-Opelika AL (CBSA)
# Auburn, IL ---Taylorville IL (CBSA)
# Auburn, IN ---Auburn IN (CBSA)
# Auburn, NE ---Ontario OR-ID  (CBSA)
# Auburn, NY ---Syracuse NY (CBSA)
# Augusta-Richmond County, GA--SC ---Augusta (DMA)
# Augusta, KS ---Wichita KS (CBSA)
# Augusta, ME ---Boulder CO  (CBSA)
# Aumsville, OR ---Salem OR (CBSA)
# Aurora, MO ---Springfield MO (CBSA)
# Aurora, NE ---Grand Island NE (CBSA)
# Austin, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Austin, TX ---Austin (DMA)
# Ava, MO ---Branson MO (CBSA)
# Avalon, CA ---Los Angeles-Long Beach-Anaheim CA (CBSA)
# Avenal, CA ---Hanford-Corcoran CA (CBSA)
# Avon, NY ---Rochester NY (CBSA)
# Avondale--Goodyear, AZ ---Phoenix
# Avra Valley, AZ ---Tucson
# Aztec, NM ---Farmington NM (CBSA)
# Bad Axe, MI ---Bay City MI (CBSA)
# Bainbridge, GA ---Tallahassee FL (CBSA)
# Baker City, OR ---Lewiston ID-WA (CBSA)
# Bakersfield, CA ---Bakersfield CA (CBSA)
# Bald Knob, AR ---Paragould AR (CBSA)
# Baldwin City, KS ---Lawrence KS (CBSA)
# Baldwin, WI ---Menomonie WI (CBSA)
# Ballinger, TX ---San Angelo TX (CBSA)
# Baltimore, MD ---Baltimore
# Baltimore, OH ---Columbus-Tupelo-West Point (DMA)
# Bamberg, SC ---Charlotte-Gastonia-Concord NC-SC (CBSA)
# Bandon, OR ---Eugene OR (DMA)
# Bangor, ME ---Boulder CO  (CBSA)
# Bar Harbor, ME ---Boston
# Baraboo, WI ---Baraboo WI (CBSA)
# Barbourville, KY ---Somerset KY (CBSA)
# Bardstown, KY ---Frankfort KY (CBSA)
# Barnesville, GA ---Warner Robins GA (CBSA)
# Barnesville, OH ---Wheeling WV-OH (CBSA)
# Barnstable Town, MA ---Providence-New Bedford (DMA)
# Barnwell, SC ---Charlotte-Gastonia-Concord NC-SC (CBSA)
# Barre--Montpelier, VT ---Plattsburgh NY (CBSA)
# Barron, WI ---Menomonie WI (CBSA)
# Barrow, AK ---Victoria (DMA)
# Barstow, CA ---Riverside-San Bernardino-Ontario CA (CBSA)
# Bartlesville, OK ---Tulsa OK (CBSA)
# Bartlett, TX ---Killeen-Temple-Fort Hood TX (CBSA)
# Basalt--El Jebel, CO ---Canon City CO (CBSA)
# Basehor, KS ---Lawrence KS (CBSA)
# Bastrop, LA ---Monroe LA (CBSA)
# Bastrop, TX ---Austin (DMA)
# Batavia, NY ---Batavia NY (CBSA)
# Batesburg-Leesville, SC ---Charlotte-Gastonia-Concord NC-SC (CBSA)
# Batesville, AR ---Searcy AR (CBSA)
# Batesville, IN ---Greensburg IN (CBSA)
# Batesville, MS ---Oxford MS (CBSA)
# Bath, NY ---Rochester NY (CBSA)
# Baton Rouge, LA ---Baton Rouge LA  (CBSA)
# Battle Creek, MI ---Battle Creek MI (CBSA)
# Battle Mountain, NV ---Elko NV (CBSA)
# Battlement Mesa, CO ---Farmington NM (CBSA)
# Baxley, GA ---Tallahassee et al FL-GA (DMA)
# Baxter Springs, KS ---Joplin MO (CBSA)
# Bay City, MI ---Bay City MI (CBSA)
# Bay City, TX ---Brownsville-Harlingen TX (CBSA)
# Bay Minette, AL ---Daphne-Fairhope AL (CBSA)
# Bayard, NM ---Silver City NM (CBSA)
# Bayfield, CO ---Farmington NM (CBSA)
# Bealeton, VA ---Winston-Salem NC  (CBSA)
# Beardstown, IL ---Jacksonville NC  (CBSA)
# Beatrice, NE ---Fremont NE (CBSA)
# Beaufort--Port Royal, SC ---Hilton Head Island-Beaufort SC (CBSA)
# Beaumont, TX ---Beaumont-Port Arthur (DMA)
# Beaver Dam, KY ---Madisonville KY (CBSA)
# Beaver Dam, WI ---Chicago-Naperville-Joliet IL-IN-WI (CBSA)
# Beaver, UT ---Fargo-Valley City (DMA)
# Becker, MN ---St. Cloud MN (CBSA)
# Beckley, WV ---Beckley WV (CBSA)
# Bedford, IN ---Beeville TX  (CBSA)
# Bedford, NY ---New Haven-Milford CT (CBSA)
# Bedford, PA ---Johnstown-Altoona (DMA)
# Bedford, VA ---Roanoke VA (CBSA)
# Beebe, AR ---Searcy AR (CBSA)
# Beecher, IL ---Chicago
# Beeville, TX ---Corpus Christi TX (CBSA)
# Belding, MI ---Ionia MI (CBSA)
# Belfair, WA ---Seattle/Tacoma
# Belfast, ME ---Boulder CO  (CBSA)
# Belgrade, MT ---Butte-Bozeman (DMA)
# Belle Fourche, SD ---Spearfish SD (CBSA)
# Belle Glade, FL ---West Palm Beach
# Belle Plaine, MN ---Minneapolis-Saint Paul (DMA)
# Bellefontaine, OH ---Bellefontaine OH (CBSA)
# Bellefonte, PA ---State College PA (CBSA)
# Bellevue, IA ---Dubuque IA (CBSA)
# Bellevue, OH ---Sandusky OH (CBSA)
# Bellingham, WA ---Washington-Arlington-Alexandria DC-VA-MD-WV (CBSA)
# Bellows Falls, VT--NH ---Clarksburg-Weston (DMA)
# Bells, TN ---Jackson TN (DMA)
# Bellville, TX ---Brenham TX (CBSA)
# Beloit, KS ---Hastings NE (CBSA)
# Beloit, WI--IL ---Janesville WI (CBSA)
# Belterra, TX ---Austin (DMA)
# Belton, SC ---Brevard NC (CBSA)
# Belvidere, NJ--PA ---East Stroudsburg PA (CBSA)
# Belzoni, MS ---Indianola MS (CBSA)
# Bemidji, MN ---Bemidji MN (CBSA)
# Bend, OR ---Eugene-Springfield OR (CBSA)
# Bennettsville, SC ---Laurinburg NC (CBSA)
# Bennington, VT ---Clarksburg-Weston (DMA)
# Benson, AZ ---Tucson
# Benson, MN ---Willmar MN (CBSA)
# Benson, NC ---Raleigh-Durham (Fayetteville) (DMA)
# Benton City, WA ---Yakima-Pasco-Richland-Kennewick (DMA)
# Benton Harbor--St. Joseph--Fair Plain, MI ---Niles-Benton Harbor MI (CBSA)
# Benton, IL ---Mount Vernon IL (CBSA)
# Benton, KY ---Murray KY (CBSA)
# Benton, LA ---Shreveport-Bossier City LA (CBSA)
# Berea, KY ---Danville KY (CBSA)
# Berlin, NH ---Boulder CO  (CBSA)
# Berlin, WI ---Chicago-Naperville-Joliet IL-IN-WI (CBSA)
# Berne, IN ---Celina OH (CBSA)
# Berrien Springs, MI ---Niles-Benton Harbor MI (CBSA)
# Berryville, AR ---Branson MO (CBSA)
# Berryville, VA ---Winston-Salem NC  (CBSA)
# Bethany, MO ---Maryville MO (CBSA)
# Bethel, AK ---Victoria (DMA)
# Bethel, OH ---Cincinnati (DMA)
# Beulah, ND ---Glendive MT (DMA)
# Bicknell, IN ---Washington IN (CBSA)
# Big Bear City, CA ---Riverside-San Bernardino-Ontario CA (CBSA)
# Big Lake, TX ---San Angelo TX (CBSA)
# Big Pine Key, FL ---Naples-Marco Island FL (CBSA)
# Big Rapids, MI ---Traverse City-Cadillac (DMA)
# Big Spring, TX ---Houston
# Big Stone Gap, VA ---Tri-Cities TN-VA (DMA)
# Billings, MT ---Billings MT (CBSA)
# Binghamton, NY--PA ---Sayre PA (CBSA)
# Birch Bay, WA ---Victoria (DMA)
# Birmingham, AL ---Birmingham (Anniston and Tuscaloosa) (DMA)
# Bisbee, AZ ---Tucson
# Biscoe, NC ---Rockingham NC (CBSA)
# Bishop, CA ---Fresno-Visalia (DMA)
# Bishop, TX ---Corpus Christi TX (CBSA)
# Bishopville, SC ---Florence SC (CBSA)
# Bismarck, ND ---Pierre SD (CBSA)
# Black River Falls, WI ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Blackfoot, ID ---Blackfoot ID (CBSA)
# Blacksburg, VA ---Blacksburg-Christiansburg-Radford VA (CBSA)
# Blackshear, GA ---Brunswick GA (CBSA)
# Blackstone, VA ---Roanoke Rapids NC (CBSA)
# Blackwell, OK ---Stillwater OK (CBSA)
# Blair, NE ---Omaha (DMA)
# Blairsville, PA ---Indiana PA (CBSA)
# Blakely, GA ---Dothan (DMA)
# Blanchard, OK ---Oklahoma City (DMA)
# Blanchester, OH ---Dayton OH (CBSA)
# Blanding, UT ---Farmington NM (CBSA)
# Blissfield, MI ---Adrian MI (CBSA)
# Bloomer, WI ---La Crosse-Eau Claire (DMA)
# Bloomfield, IN ---Bloomington IN (CBSA)
# Bloomfield, NM ---Farmington NM (CBSA)
# Bloomington--Normal, IL ---Bloomington IL (CBSA)
# Bloomington, IN ---Bloomington IN (CBSA)
# Bloomsburg--Berwick, PA ---Bloomsburg-Berwick PA (CBSA)
# Blountstown, FL ---Panama City-Lynn Haven FL (CBSA)
# Blue Earth, MN ---New Ulm MN (CBSA)
# Bluefield, WV--VA ---Bluefield WV-VA (CBSA)
# Bluffton, IN ---Fort Wayne (DMA)
# Bluffton, OH ---Findlay OH (CBSA)
# Blythe, CA--AZ ---Yuma-El Centro (DMA)
# Blytheville, AR ---Blytheville AR (CBSA)
# Boardman, OR ---Yakima-Pasco-Richland-Kennewick (DMA)
# Boerne, TX ---San Antonio TX (CBSA)
# Bogalusa, LA ---Bogalusa LA (CBSA)
# Boiling Spring Lakes, NC ---Wilmington NC (CBSA)
# Boiling Springs, NC ---Shelbyville TN  (CBSA)
# Boise City, ID ---Boise (DMA)
# Bolivar, MO ---Springfield MO (CBSA)
# Bolivar, OH ---Cleveland-Akron (Canton) (DMA)
# Bolivar, TN ---Jackson TN (DMA)
# Bonadelle Ranchos-Madera Ranchos, CA ---Madera CA (CBSA)
# Bonham, TX ---Sulphur Springs TX (CBSA)
# Bonifay, FL ---Dothan (DMA)
# Bonita Springs, FL ---Cape Coral-Fort Myers FL (CBSA)
# Bonneauville, PA ---Gettysburg PA (CBSA)
# Bonners Ferry, ID ---Spokane WA (CBSA)
# Boone, IA ---Boone IA (CBSA)
# Boone, NC ---Boone NC (CBSA)
# Booneville, AR ---Ft. Smith
# Booneville, MS ---Corinth MS (CBSA)
# Boonville, IN ---Evansville IN-KY (CBSA)
# Boonville, MO ---Marshall MO (CBSA)
# Borger, TX ---Ames IA  (CBSA)
# Boscobel, WI ---Platteville WI (CBSA)
# Boston, MA--NH--RI ---Boston
# Boulder City, NV ---Las Vegas-Paradise NV (CBSA)
# Boulder, CO ---Fort Dodge IA  (CBSA)
# Bowie, TX ---Dallas-Fort Worth (DMA)
# Bowling Green, KY ---Pottsville PA  (CBSA)
# Bowling Green, MO ---Hannibal MO (CBSA)
# Bowling Green, OH ---Cleveland-Akron (Canton) (DMA)
# Box Elder, SD ---Rapid City (DMA)
# Boyne City, MI ---Traverse City MI (CBSA)
# Bozeman, MT ---Bozeman MT (CBSA)
# Brackettville, TX ---Fredericksburg TX (CBSA)
# Bradford, PA--NY ---Bradford PA (CBSA)
# Brady, TX ---Fredericksburg TX (CBSA)
# Braidwood--Coal City--Wilmington, IL ---Chicago
# Brainerd, MN ---Brainerd MN (CBSA)
# Brandon, SD ---Sioux Falls (Mitchell) (DMA)
# Branson, MO ---Branson MO (CBSA)
# Brattleboro, VT--NH ---Springfield-Holyoke (DMA)
# Brawley, CA ---El Centro CA (CBSA)
# Brazoria, TX ---El Campo TX (CBSA)
# Breaux Bridge, LA ---Lafayette LA (CBSA)
# Breckenridge, CO ---Denver-Aurora CO (CBSA)
# Breckenridge, TX ---Abilene TX (CBSA)
# Breese, IL ---Centralia IL (CBSA)
# Bremen, GA ---Cedartown GA (CBSA)
# Bremen, IN ---Plymouth IN (CBSA)
# Bremerton, WA ---Seattle/Tacoma
# Brenham, TX ---Brenham TX (CBSA)
# Brent, AL ---Tuscaloosa AL (CBSA)
# Brevard, NC ---Brevard NC (CBSA)
# Brewton, AL ---Pensacola-Ferry Pass-Brent FL (CBSA)
# Bridgeport--Stamford, CT--NY ---New York (Northern New Jersey)
# Bridgeport, TX ---Dallas-Fort Worth (DMA)
# Bridgeton, NJ ---Wilmington (DMA)
# Bridgeville, DE ---Wilmington (DMA)
# Brillion, WI ---Green Bay WI (CBSA)
# Brinkley, AR ---Searcy AR (CBSA)
# Bristol--Bristol, TN--VA ---Johnson City TN (CBSA)
# Bristow, OK ---Tulsa OK (CBSA)
# Broadway, VA ---Harrisonburg VA (CBSA)
# Brockport, NY ---Batavia NY (CBSA)
# Brockway, PA ---DuBois PA (CBSA)
# Brodhead, WI ---Janesville WI (CBSA)
# Broken Bow, NE ---Lexington NE (CBSA)
# Broken Bow, OK ---Sulphur Springs TX (CBSA)
# Brookfield, MO ---Kirksville MO (CBSA)
# Brookhaven, MS ---Brookhaven MS (CBSA)
# Brookings, OR ---Eugene OR (DMA)
# Brookings, SD ---Brookings SD (CBSA)
# Brooklyn, MI ---Jackson MI (CBSA)
# Brookshire, TX ---Houston
# Brookville, PA ---DuBois PA (CBSA)
# Brownfield, TX ---Levelland TX (CBSA)
# Browning, MT ---Kalispell MT (CBSA)
# Browns Mills--Fort Dix, NJ ---Allentown-Bethlehem-Easton PA-NJ (CBSA)
# Brownstown, IN ---Seymour IN (CBSA)
# Brownsville, TN ---Jackson TN (DMA)
# Brownsville, TX ---Brownsville-Harlingen TX (CBSA)
# Brownwood, TX ---Abilene TX (CBSA)
# Brunswick, GA ---Brunswick GA (CBSA)
# Brunswick, MD--VA ---Winston-Salem NC  (CBSA)
# Brunswick, ME ---Boulder CO  (CBSA)
# Brush, CO ---Greeley CO (CBSA)
# Bryan, OH ---Angola IN (CBSA)
# Buckeye, AZ ---Phoenix
# Buckhannon, WV ---Clarksburg WV (CBSA)
# Buckhead (Bryan County), GA ---Savannah (DMA)
# Buckner, MO ---Kansas City MO-KS (CBSA)
# Bucyrus, OH ---Marion OH (CBSA)
# Buena Vista, CO ---Canon City CO (CBSA)
# Buena Vista, VA ---Sterling IL  (CBSA)
# Buffalo, MN ---St. Cloud MN (CBSA)
# Buffalo, MO ---Lebanon MO (CBSA)
# Buffalo, NY ---Buffalo - Niagara Region (DMA)
# Buffalo, WY ---Sheridan WY (CBSA)
# Buhl, ID ---Twin Falls ID (CBSA)
# Buies Creek, NC ---Raleigh-Durham (Fayetteville) (DMA)
# Bullhead City, AZ--NV ---Lake Havasu City-Kingman AZ (CBSA)
# Bunkie, LA ---Alexandria LA (DMA)
# Buras, LA ---New Orleans (DMA)
# Burgaw, NC ---Wilmington NC (CBSA)
# Burgettstown, PA ---Wheeling-Steubenville (DMA)
# Burkburnett, TX ---Elk City OK (CBSA)
# Burley, ID ---Burlington IA-IL  (CBSA)
# Burlington, CO ---Pueblo CO (CBSA)
# Burlington, IA--IL ---Macomb IL (CBSA)
# Burlington, KS ---Emporia KS (CBSA)
# Burlington, NC ---Danville VA (CBSA)
# Burlington, VT ---Plattsburgh NY (CBSA)
# Burlington, WI ---Milwaukee-Waukesha-West Allis WI (CBSA)
# Burnet, TX ---Austin-Round Rock TX (CBSA)
# Burney, CA ---Redding CA (CBSA)
# Burns, OR ---Boise City-Nampa ID (CBSA)
# Burnt Store Marina, FL ---Punta Gorda FL (CBSA)
# Bushnell, FL ---The Villages FL (CBSA)
# Bushnell, IL ---Macomb IL (CBSA)
# Butler, IN ---Auburn IN (CBSA)
# Butler, MO ---Warrensburg MO (CBSA)
# Butler, PA ---Pittsburgh (DMA)
# Butner, NC ---Durham NC (CBSA)
# Butte-Silver Bow, MT ---Butte-Silver Bow MT (CBSA)
# Byron, IL ---Rockford IL (CBSA)
# Byron, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Ca_on City, CO ---Canon City CO (CBSA)
# Cache, OK ---Elk City OK (CBSA)
# Cactus, TX ---Ames IA  (CBSA)
# Cadillac, MI ---Traverse City-Cadillac (DMA)
# Cadiz, KY ---Murray KY (CBSA)
# Cadiz, OH ---Wheeling WV-OH (CBSA)
# Cairo, GA ---Tallahassee FL (CBSA)
# Cairo, IL ---Sikeston MO (CBSA)
# Calais, ME ---Boston
# Caldwell, OH ---Parkersburg-Marietta-Vienna WV-OH (CBSA)
# Caldwell, TX ---College Station-Bryan TX (CBSA)
# Caledonia, MN ---La Crosse-Eau Claire (DMA)
# Calhoun, GA ---Calhoun GA (CBSA)
# California City, CA ---Bakersfield CA (CBSA)
# California, MO ---Jefferson City MO (CBSA)
# Calipatria, CA ---El Centro CA (CBSA)
# Calistoga, CA ---Clearlake CA (CBSA)
# Camano North, WA ---Washington-Arlington-Alexandria DC-VA-MD-WV (CBSA)
# Camano, WA ---Washington-Arlington-Alexandria DC-VA-MD-WV (CBSA)
# Camarillo, CA ---Los Angeles (DMA)
# Cambria, CA ---Hanford-Corcoran CA (CBSA)
# Cambridge City, IN ---New Castle IN (CBSA)
# Cambridge Springs, PA ---Somerset PA (CBSA)
# Cambridge, MD ---Baltimore
# Cambridge, MN ---Minneapolis-Saint Paul (DMA)
# Cambridge, OH ---Lafayette-West Lafayette IN (CBSA)
# Cambridge, WI ---Watertown-Fort Atkinson WI (CBSA)
# Camden, AR ---El Dorado AR (CBSA)
# Camden, ME ---Boulder CO  (CBSA)
# Camden, SC ---Columbia SC (DMA)
# Camden, TN ---Paris TN (CBSA)
# Camdenton, MO ---Lebanon MO (CBSA)
# Cameron, MO ---Saint Joseph (DMA)
# Cameron, TX ---Waco-Temple-Bryan (DMA)
# Camilla, GA ---Tallahassee FL (CBSA)
# Camp Verde, AZ ---Phoenix
# Campbellsville, KY ---Danville KY (CBSA)
# Canadian, TX ---Elk City OK (CBSA)
# Canby, OR ---Portland OR (DMA)
# Cannon Falls, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Canton, IL ---Canton IL (CBSA)
# Canton, MS ---Jackson MS (CBSA)
# Canton, NY ---Watertown-Fort Drum NY (CBSA)
# Canton, OH ---Cleveland-Akron (Canton) (DMA)
# Canton, SD ---Sioux Falls (Mitchell) (DMA)
# Canton, TX ---Athens-Clarke County GA  (CBSA)
# Canyon Lake, TX ---San Antonio TX (CBSA)
# Canyon, TX ---Ames IA  (CBSA)
# Cape Coral, FL ---Cape Coral-Fort Myers FL (CBSA)
# Cape Girardeau, MO--IL ---Cape Girardeau-Jackson MO-IL (CBSA)
# Captain Cook, HI ---San Francisco
# Carbondale, CO ---Canon City CO (CBSA)
# Carbondale, IL ---Carbondale IL (CBSA)
# Carey, OH ---Tiffin OH (CBSA)
# Caribou, ME ---Boulder CO  (CBSA)
# Carlinville, IL ---Jacksonville NC  (CBSA)
# Carlisle, IA ---Des Moines
# Carlsbad, NM ---Carlsbad-Artesia NM (CBSA)
# Carlton, OR ---Salem OR (CBSA)
# Carlyle, IL ---Centralia IL (CBSA)
# Carmel Valley Village, CA ---Modesto CA (CBSA)
# Carmi, IL ---Evansville IN-KY (CBSA)
# Caro, MI ---Bay City MI (CBSA)
# Carrizo Springs, TX ---Laredo (DMA)
# Carroll, IA ---Boone IA (CBSA)
# Carrollton, GA ---Cedartown GA (CBSA)
# Carrollton, KY ---Madison IN (CBSA)
# Carrollton, MO ---Marshall MO (CBSA)
# Carrollton, OH ---Wheeling-Steubenville (DMA)
# Carson City, NV ---Reno
# Cartersville, GA ---Calhoun GA (CBSA)
# Carthage, IL ---Macomb IL (CBSA)
# Carthage, MO ---Joplin MO (CBSA)
# Carthage, MS ---Jackson MS (CBSA)
# Carthage, TN ---Cookeville TN (CBSA)
# Carthage, TX ---Marshalltown IA  (CBSA)
# Caruthersville, MO ---Blytheville AR (CBSA)
# Casa Grande, AZ ---Phoenix
# Casey, IL ---Charleston-Mattoon IL (CBSA)
# Cashmere, WA ---Wenatchee WA (CBSA)
# Casper, WY ---Casper-Riverton (DMA)
# Cassville, MO ---Branson MO (CBSA)
# Castle Dale, UT ---Fargo-Valley City (DMA)
# Castle Rock, WA ---Portland OR (DMA)
# Castroville, TX ---San Antonio TX (CBSA)
# Catskill, NY ---Albany-Schenectady-Troy (DMA)
# Cazenovia, NY ---Syracuse NY (CBSA)
# Cedar City, UT ---Las Vegas NM  (CBSA)
# Cedar Rapids, IA ---Cedar Rapids IA (CBSA)
# Cedar Springs, MI ---Grand Rapids-Wyoming MI (CBSA)
# Cedaredge, CO ---Farmington NM (CBSA)
# Cedartown, GA ---Cedartown GA (CBSA)
# Cedarville, OH ---Springfield OH (CBSA)
# Celina, OH ---Celina OH (CBSA)
# Center, TX ---Nacogdoches TX (CBSA)
# Centerville, IA ---Kirksville MO (CBSA)
# Central City--Greenville, KY ---Madisonville KY (CBSA)
# Central City, NE ---Grand Island NE (CBSA)
# Centralia, IL ---Centralia IL (CBSA)
# Centralia, MO ---Mexico MO (CBSA)
# Centralia, WA ---Seattle/Tacoma
# Centre, AL ---Gadsden AL (CBSA)
# Centreville, MD ---Baltimore
# Century, FL--AL ---Pensacola-Ferry Pass-Brent FL (CBSA)
# Chadron, NE ---Cheyenne-Scottsbluff (DMA)
# Chaffee, MO ---Cape Girardeau-Jackson MO-IL (CBSA)
# Chambersburg, PA ---Gettysburg PA (CBSA)
# Champaign, IL ---Champaign-Urbana IL (CBSA)
# Chandler, OK ---Shawnee OK (CBSA)
# Chanute, KS ---Pittsburg KS (CBSA)
# Chaparral, NM ---El Paso (Las Cruces) (DMA)
# Chardon, OH ---Cleveland-Elyria-Mentor OH (CBSA)
# Chariton, IA ---Des Moines
# Charles City, IA ---Cedar Rapids IA (CBSA)
# Charles Town--Ranson, WV ---Winston-Salem NC  (CBSA)
# Charleston--North Charleston, SC ---Hilton Head Island-Beaufort SC (CBSA)
# Charleston, IL ---Charleston-Mattoon IL (CBSA)
# Charleston, MO ---Sikeston MO (CBSA)
# Charleston, MS ---Grenada MS (CBSA)
# Charleston, WV ---Charleston WV (CBSA)
# Charlestown, IN ---Madison IN (CBSA)
# Charlestown, NH ---Boulder CO  (CBSA)
# Charlestown, RI ---Norwich-New London CT (CBSA)
# Charlevoix, MI ---Traverse City MI (CBSA)
# Charlotte, MI ---Lansing-East Lansing MI (CBSA)
# Charlotte, NC--SC ---Charlotte (DMA)
# Charlottesville, VA ---Charlottesville (DMA)
# Chase City, VA ---Hereford TX  (CBSA)
# Chatfield, MN ---Menomonie WI (CBSA)
# Chattahoochee, FL ---Tallahassee FL (CBSA)
# Chattanooga, TN--GA ---Chattanooga (DMA)
# Cheboygan, MI ---Traverse City MI (CBSA)
# Checotah, OK ---Muskogee OK (CBSA)
# Chelan, WA ---Wenatchee WA (CBSA)
# Chelsea, MI ---Ann Arbor MI (CBSA)
# Cheney, WA ---Spokane WA (CBSA)
# Cheraw, SC ---Rockingham NC (CBSA)
# Cherokee Village, AR ---El Dorado AR (CBSA)
# Cherokee, IA ---Worthington MN (CBSA)
# Cherryville, NC ---Shelbyville TN  (CBSA)
# Chesapeake Beach, MD ---Washington et al DC-MD (DMA)
# Chesnee, SC ---Forest City NC (CBSA)
# Chester, IL ---Cape Girardeau-Jackson MO-IL (CBSA)
# Chester, NY ---New York (Northern New Jersey)
# Chester, SC ---Charlotte (DMA)
# Chestertown, MD ---Baltimore
# Chetek, WI ---Menomonie WI (CBSA)
# Cheyenne, WY ---Fort Dodge IA  (CBSA)
# Chicago, IL--IN ---Chicago
# Chickasha, OK ---Oklahoma City (DMA)
# Chico, CA ---Chico-Redding CA (DMA)
# Childress, TX ---Elk City OK (CBSA)
# Chillicothe, MO ---Marshall MO (CBSA)
# Chillicothe, OH ---Chillicothe OH (CBSA)
# Chilton, WI ---Appleton WI (CBSA)
# Chinle, AZ ---Gallup NM (CBSA)
# Chino Valley, AZ ---Phoenix
# Chipley, FL ---Dothan (DMA)
# Chisholm, MN ---Duluth MN-WI (CBSA)
# Chittenango, NY ---Syracuse NY (CBSA)
# Chowchilla, CA ---Madera CA (CBSA)
# Christopher, IL ---Carbondale IL (CBSA)
# Church Point, LA ---Monroe LA (CBSA)
# Churchville, NY ---Rochester NY (CBSA)
# Cincinnati, OH--KY--IN ---Cincinnati (DMA)
# Circleville, OH ---Chillicothe OH (CBSA)
# Cisco, TX ---Abilene TX (CBSA)
# Clanton, AL ---Talladega-Sylacauga AL (CBSA)
# Clare, MI ---Mount Pleasant MI (CBSA)
# Claremont, NH ---Boulder CO  (CBSA)
# Claremore, OK ---Tulsa OK (CBSA)
# Clarinda, IA ---Maryville MO (CBSA)
# Clarion, IA ---Boone IA (CBSA)
# Clarion, PA ---Okeechobee FL  (CBSA)
# Clarksburg, WV ---Clarksburg WV (CBSA)
# Clarksdale, MS ---Clarksdale MS (CBSA)
# Clarksville, AR ---Russellville AR (CBSA)
# Clarksville, TN--KY ---Clarksville TN-KY (CBSA)
# Clarksville, TX ---Sulphur Springs TX (CBSA)
# Claxton, GA ---Hinesville-Fort Stewart GA (CBSA)
# Clay Center, KS ---Emporia KS (CBSA)
# Clayton, GA ---Gainesville GA (CBSA)
# Cle Elum, WA ---Wenatchee WA (CBSA)
# Clear Lake, IA ---Boone IA (CBSA)
# Clearfield, PA ---DuBois PA (CBSA)
# Clearlake Riviera, CA ---Los Angeles (DMA)
# Clearlake, CA ---Clearlake CA (CBSA)
# Clearwood, WA ---Seattle/Tacoma
# Cleburne, TX ---Dallas-Fort Worth (DMA)
# Cleveland, GA ---Gainesville GA (CBSA)
# Cleveland, MS ---Cleveland MS (CBSA)
# Cleveland, OH ---Cleveland
# Cleveland, OK ---Tulsa OK (CBSA)
# Cleveland, TN ---Cleveland TN (CBSA)
# Cleveland, TX ---Huntsville TX (CBSA)
# Clewiston, FL ---Fort Myers-Naples (DMA)
# Clifton Forge, VA ---Roanoke VA (CBSA)
# Clifton Springs, NY ---Norwich-New London CT (CBSA)
# Clifton, AZ ---Silver City NM (CBSA)
# Clifton, TX ---Waco-Temple-Bryan (DMA)
# Clinton, IA--IL ---Clinton IA (CBSA)
# Clinton, IL ---Decatur IL (CBSA)
# Clinton, IN ---Terre Haute (DMA)
# Clinton, MO ---Warrensburg MO (CBSA)
# Clinton, NC ---Goldsboro NC (CBSA)
# Clinton, OK ---Elk City OK (CBSA)
# Clinton, SC ---Forest City NC (CBSA)
# Clintonville, WI ---Shawano WI Micro (CBSA)
# Cloquet, MN ---Duluth MN-WI (CBSA)
# Clover, SC ---Shelbyville TN  (CBSA)
# Cloverdale, CA ---Clearlake CA (CBSA)
# Clovis, NM ---Levelland TX (CBSA)
# Clyde, OH ---Fremont OH (CBSA)
# Clyde, TX ---Abilene TX (CBSA)
# Coalinga, CA ---Hanford-Corcoran CA (CBSA)
# Coamo, PR ---Ponce (Region) (DMA)
# Cobleskill, NY ---Albany-Schenectady-Troy (DMA)
# Cochran, GA ---Warner Robins GA (CBSA)
# Coco--Salinas, PR ---Ponce (Region) (DMA)
# Cody, WY ---Billings MT (CBSA)
# Coeburn, VA ---Tri-Cities TN-VA (DMA)
# Coeur d'Alene, ID ---Spokane WA (CBSA)
# Coffeyville, KS--OK ---Tulsa OK (CBSA)
# Cokato, MN ---Hutchinson MN (CBSA)
# Colby, KS ---Lexington NE (CBSA)
# Colchester, CT ---Norwich-New London CT (CBSA)
# Cold Spring, MN ---St. Cloud MN (CBSA)
# Cold Spring, NY ---New York (Northern New Jersey)
# Coldwater, MI ---Coldwater MI (CBSA)
# Coldwater, OH ---Celina OH (CBSA)
# Coleman, TX ---Abilene TX (CBSA)
# Colfax, CA ---Sacramento
# Colfax, WA ---Moscow ID (CBSA)
# College Station--Bryan, TX ---College Station-Bryan TX (CBSA)
# Collinsville, OK ---Tulsa OK (CBSA)
# Colonial Beach, VA ---Washington et al DC-MD (DMA)
# Colorado City, AZ--UT ---Lake Havasu City-Kingman AZ (CBSA)
# Colorado City, TX ---Brownsville-Harlingen TX (CBSA)
# Colorado Springs, CO ---Colorado Springs CO (CBSA)
# Columbia City, IN ---Huntington IN (CBSA)
# Columbia Falls, MT ---Kalispell MT (CBSA)
# Columbia, KY ---Glasgow KY (CBSA)
# Columbia, MO ---Jefferson City MO (CBSA)
# Columbia, MS ---Bogalusa LA (CBSA)
# Columbia, SC ---Columbia SC (DMA)
# Columbia, TN ---Lewisburg TN (CBSA)
# Columbiana, AL ---Birmingham-Hoover AL (CBSA)
# Columbiana, OH ---Youngstown-Warren-Boardman OH-PA (CBSA)
# Columbus AFB, MS ---Columbus MS (CBSA)
# Columbus, GA--AL ---Columbus GA (DMA)
# Columbus, IN ---Columbus IN (CBSA)
# Columbus, KS ---Pittsburg KS (CBSA)
# Columbus, MS ---Columbus MS (CBSA)
# Columbus, NE ---Columbus NE (CBSA)
# Columbus, OH ---Columbus-Tupelo-West Point (DMA)
# Columbus, TX ---Brenham TX (CBSA)
# Columbus, WI ---Watertown-Fort Atkinson WI (CBSA)
# Colusa, CA ---Chico-Redding CA (DMA)
# Colville, WA ---Spokane WA (CBSA)
# Comanche, TX ---Killeen-Temple-Fort Hood TX (CBSA)
# Comfort, TX ---Fredericksburg TX (CBSA)
# Commerce, GA ---Jefferson GA (CBSA)
# Commerce, TX ---Sulphur Springs TX (CBSA)
# Concord, CA ---San Francisco
# Concord, NC ---Charlotte (DMA)
# Concord, NH ---Boulder CO  (CBSA)
# Concordia, KS ---Hastings NE (CBSA)
# Conesus Lake, NY ---Rochester NY (CBSA)
# Conneaut, OH ---Ashtabula OH (CBSA)
# Connell, WA ---Yakima-Pasco-Richland-Kennewick (DMA)
# Connersville, IN ---Richmond IN (CBSA)
# Conrad, MT ---Great Falls (DMA)
# Conroe--The Woodlands, TX ---Houston
# Constantine, MI ---Elkhart-Goshen IN (CBSA)
# Conway, AR ---Little Rock-North Little Rock AR (CBSA)
# Cookeville, TN ---Cookeville TN (CBSA)
# Coolidge, AZ ---Phoenix
# Coopersville, MI ---Grand Rapids-Wyoming MI (CBSA)
# Coos Bay, OR ---Eugene OR (DMA)
# Coquille, OR ---Eugene OR (DMA)
# Corcoran, CA ---Hanford-Corcoran CA (CBSA)
# Cordele, GA ---Warner Robins GA (CBSA)
# Corinth, MS ---Corinth MS (CBSA)
# Corinth, NY ---Glens Falls NY (CBSA)
# Cornelia--Baldwin, GA ---Gainesville GA (CBSA)
# Corning, AR ---Paragould AR (CBSA)
# Corning, CA ---Chico-Redding CA (DMA)
# Corning, NY ---Sayre PA (CBSA)
# Corona de Tucson, AZ ---Tucson
# Corpus Christi, TX ---Corpus Christi TX (CBSA)
# Corry, PA ---Okeechobee FL  (CBSA)
# Corsicana, TX ---Athens-Clarke County GA  (CBSA)
# Cortez, CO ---Farmington NM (CBSA)
# Cortland, NY ---Syracuse NY (CBSA)
# Corvallis, OR ---Salem OR (CBSA)
# Corydon, IN ---Beeville TX  (CBSA)
# Coshocton, OH ---Coshocton OH (CBSA)
# Cottage Grove, OR ---Eugene OR (DMA)
# Cottonport, LA ---Alexandria LA (DMA)
# Cottonwood--Verde Village, AZ ---Phoenix
# Cottonwood, CA ---Redding CA (CBSA)
# Cotulla, TX ---Laredo (DMA)
# Country Lakes, MD ---Washington et al DC-MD (DMA)
# Covington, IN ---Danville IL (CBSA)
# Covington, OH ---Sidney OH (CBSA)
# Covington, TN ---Blytheville AR (CBSA)
# Covington, VA ---Roanoke-Lynchburg (DMA)
# Coxsackie, NY ---Albany-Schenectady-Troy (DMA)
# Cozad, NE ---Lexington NE (CBSA)
# Craig, CO ---Rock Springs WY (CBSA)
# Crane, TX ---Big Spring TX (CBSA)
# Crawfordsville, IN ---Crawfordsville IN (CBSA)
# Crawfordville, FL ---Tallahassee FL (CBSA)
# Crescent City, CA ---Redding CA (CBSA)
# Crescent City, FL ---Palatka FL (CBSA)
# Cresco, IA ---Cedar Rapids IA (CBSA)
# Cresson, PA ---Johnstown-Altoona (DMA)
# Creston, IA ---Maryville MO (CBSA)
# Crestview, FL ---Crestview-Fort Walton Beach-Destin FL (CBSA)
# Creswell, OR ---Eugene OR (DMA)
# Crete, NE ---Columbus NE (CBSA)
# Crewe, VA ---Kingsport-Bristol-Bristol TN-VA (CBSA)
# Crisfield, MD ---Norfolk-Portsmouth-Newport News (DMA)
# Crittenden, KY ---Cincinnati (DMA)
# Crockett, TX ---Palestine TX (CBSA)
# Crooked Lake Park, FL ---West Palm Beach
# Crookston, MN ---Fargo ND-MN (CBSA)
# Crooksville, OH ---Zanesville (DMA)
# Crosby, MN ---Brainerd MN (CBSA)
# Cross City, FL ---Lake City FL (CBSA)
# Crossett, AR ---Monroe LA (CBSA)
# Crossville, TN ---Crossville TN (CBSA)
# Crowley, LA ---Opelousas-Eunice LA (CBSA)
# Crozet, VA ---Sterling IL  (CBSA)
# Crystal City, TX ---Brownsville-Harlingen TX (CBSA)
# Crystal River, FL ---Homosassa Springs FL (CBSA)
# Crystal Springs, MS ---Jackson MS (CBSA)
# Cuba, MO ---Rolla MO (CBSA)
# Cuero, TX ---Victoria TX (CBSA)
# Cullman, AL ---Cullman AL (CBSA)
# Cullowhee, NC ---Brevard NC (CBSA)
# Culpeper, VA ---Charlottesville (DMA)
# Cumberland, KY ---Tri-Cities TN-VA (DMA)
# Cumberland, MD--WV--PA ---Cumberland MD-WV (CBSA)
# Curwensville, PA ---DuBois PA (CBSA)
# Cushing, OK ---Stillwater OK (CBSA)
# Cut Bank, MT ---Great Falls (DMA)
# Cuthbert, GA ---Columbus GA (DMA)
# Cynthiana, KY ---Lincoln IL  (CBSA)
# Dahlgren, VA--MD ---Washington et al DC-MD (DMA)
# Dahlonega, GA ---Gainesville GA (CBSA)
# Daingerfield, TX ---Longview TX (CBSA)
# Dalhart, TX ---Ames IA  (CBSA)
# Dallas--Fort Worth--Arlington, TX ---Dallas-Fort Worth-Arlington TX (CBSA)
# Dallas, OR ---Salem OR (CBSA)
# Dalton, GA ---Dalton GA (CBSA)
# Dalton, OH ---Cleveland-Akron (Canton) (DMA)
# Danbury, CT--NY ---New Haven-Milford CT (CBSA)
# Dandridge, TN ---Sevierville TN (CBSA)
# Dansville, NY ---Rochester NY (CBSA)
# Danville, IL ---Danville IL (CBSA)
# Danville, KY ---Danville KY (CBSA)
# Danville, VA--NC ---Danville VA (CBSA)
# Daphne--Fairhope, AL ---Daphne-Fairhope AL (CBSA)
# Darbydale, OH ---Columbus-Tupelo-West Point (DMA)
# Darien, GA ---Brunswick GA (CBSA)
# Davenport, IA--IL ---Davenport-Rock Island-Moline (DMA)
# David City, NE ---Columbus NE (CBSA)
# Davis Junction, IL ---Evansville IN-KY (CBSA)
# Davis, CA ---Sacramento
# Davis, OK ---Shawnee OK (CBSA)
# Dawson, GA ---Columbus GA (DMA)
# Dayton, NV ---Reno
# Dayton, OH ---Dayton OH (CBSA)
# Dayton, TN ---Cleveland TN (CBSA)
# Dayton, TX ---Houston
# Dayton, WA ---Lewiston ID-WA (CBSA)
# De Funiak Springs, FL ---Crestview-Fort Walton Beach-Destin FL (CBSA)
# De Motte, IN ---Chicago
# De Queen, AR ---Ft. Smith
# De Soto, KS ---Lawrence KS (CBSA)
# De Soto, MO ---Farmington MO (CBSA)
# De Witt, IA ---Davenport-Rock Island-Moline (DMA)
# Decatur, AL ---Decatur AL (CBSA)
# Decatur, IL ---Decatur IL (CBSA)
# Decatur, IN ---Fort Wayne (DMA)
# Decatur, TX ---Dallas-Fort Worth (DMA)
# Decorah, IA ---Cedar Rapids IA (CBSA)
# Deer Lodge, MT ---Butte-Silver Bow MT (CBSA)
# Deer Park, WA ---Spokane WA (CBSA)
# Deerwood, TX ---Dallas
# Defiance, OH ---Van Wert OH (CBSA)
# DeKalb, IL ---Rockford IL (CBSA)
# Del Rio, TX ---San Angelo TX (CBSA)
# Delano, CA ---Visalia-Porterville CA (CBSA)
# Delano, MN ---Minneapolis-Saint Paul (DMA)
# Delavan, WI ---Whitewater WI (CBSA)
# Delhi, LA ---Vicksburg MS (CBSA)
# Delhi, NY ---Albany-Schenectady-Troy (DMA)
# Dell Rapids, SD ---Sioux Falls (Mitchell) (DMA)
# Delphi, IN ---Lafayette IN (DMA)
# Delphos, OH ---Van Wert OH (CBSA)
# Delta, CO ---Farmington NM (CBSA)
# Delta, OH ---Adrian MI (CBSA)
# Delta, UT ---Fargo-Valley City (DMA)
# Deltona, FL ---Orlando
# Deming, NM ---Deming NM (CBSA)
# Demopolis, AL ---Tuscaloosa AL (CBSA)
# Denison, IA ---Ontario OR-ID  (CBSA)
# Denmark, SC ---Charlotte-Gastonia-Concord NC-SC (CBSA)
# Denton Southwest, TX ---Dallas-Fort Worth-Arlington TX (CBSA)
# Denton--Lewisville, TX ---Dallas-Fort Worth-Arlington TX (CBSA)
# Denton, MD ---Baltimore
# Denver City, TX ---Brownsville-Harlingen TX (CBSA)
# Denver--Aurora, CO ---Denver-Aurora CO (CBSA)
# DeQuincy, LA ---Lake Charles (DMA)
# DeRidder, LA ---De Ridder LA (CBSA)
# Dermott, AR ---Greenville MS (CBSA)
# Des Moines, IA ---Des Moines
# Desert Hot Springs, CA ---Redding CA (CBSA)
# Detroit Lakes, MN ---Fargo ND-MN (CBSA)
# Detroit, MI ---Detroit (DMA)
# Devils Lake, ND ---Fargo ND-MN (CBSA)
# Devine, TX ---San Antonio TX (CBSA)
# DeWitt, AR ---Little Rock-Pine Bluff (DMA)
# Dexter, MO ---Sikeston MO (CBSA)
# Diamondhead, MS ---Guymon OK  (CBSA)
# Diboll, TX ---Nacogdoches TX (CBSA)
# Dickinson, ND ---Glendive MT (DMA)
# Dickson, TN ---Clarksville TN-KY (CBSA)
# Dilley, TX ---San Antonio TX (CBSA)
# Dillon, MT ---Butte-Silver Bow MT (CBSA)
# Dillon, SC ---Laurinburg NC (CBSA)
# Dimmitt, TX ---Plainview TX (CBSA)
# Discovery Bay, CA ---Modesto CA (CBSA)
# Dixon, CA ---Sacramento
# Dixon, IL ---Rockford IL (CBSA)
# Dodge Center, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Dodge City, KS ---Elk City OK (CBSA)
# Dodgeville, WI ---Platteville WI (CBSA)
# Donaldsonville, LA ---Houma-Bayou Cane-Thibodaux LA (CBSA)
# Donalsonville, GA ---Dothan (DMA)
# Dorr, MI ---Grand Rapids-Wyoming MI (CBSA)
# Dos Palos, CA ---Merced CA (CBSA)
# Dothan, AL ---Dothan (DMA)
# Douglas, AZ ---Tucson
# Douglas, GA ---Tallahassee et al FL-GA (DMA)
# Douglas, MI ---Holland MI (CBSA)
# Douglas, WY ---Laramie WY (CBSA)
# Dover--Rochester, NH--ME ---Boulder CO  (CBSA)
# Dover, DE ---Wilmington (DMA)
# Dowagiac, MI ---Niles-Benton Harbor MI (CBSA)
# Downs, IL ---Bloomington IL (CBSA)
# Dryden, NY ---Sayre PA (CBSA)
# Du Quoin, IL ---Carbondale IL (CBSA)
# Dublin, GA ---Tallahassee et al FL-GA (DMA)
# Dublin, TX ---Killeen-Temple-Fort Hood TX (CBSA)
# DuBois, PA ---DuBois PA (CBSA)
# Dubuque, IA--IL ---Dubuque IA (CBSA)
# Duluth, MN--WI ---Duluth MN-WI (CBSA)
# Dumas, AR ---Little Rock-Pine Bluff (DMA)
# Dumas, TX ---Ames IA  (CBSA)
# Duncan, OK ---Oklahoma City (DMA)
# Dundee, MI ---Monroe MI (CBSA)
# Dunkirk--Fredonia, NY ---Warren PA (CBSA)
# Dunkirk, IN ---New Castle IN (CBSA)
# Dunlap, TN ---Chattanooga (DMA)
# Dunn, NC ---Fayetteville NC (CBSA)
# Durand, MI ---Flint MI (CBSA)
# Durango, CO ---Farmington NM (CBSA)
# Durant, MS ---Greenwood MS (CBSA)
# Durant, OK ---Sulphur Springs TX (CBSA)
# Durham, NC ---Durham NC (CBSA)
# Dwight, IL ---Bloomington IL (CBSA)
# Dyer, TN ---Union City TN-KY (CBSA)
# Dyersburg, TN ---Union City TN-KY (CBSA)
# Dyersville, IA ---Dubuque IA (CBSA)
# Eagar, AZ ---Gallup NM (CBSA)
# Eagle Grove, IA ---Boone IA (CBSA)
# Eagle Lake, TX ---El Campo TX (CBSA)
# Eagle Mountain South, UT ---Fargo-Valley City (DMA)
# Eagle Pass, TX ---Laredo (DMA)
# Eagle, CO ---Fort Dodge IA  (CBSA)
# Earlimart, CA ---Visalia-Porterville CA (CBSA)
# East Aurora, NY ---Syracuse NY (CBSA)
# East Liverpool, OH--WV--PA ---Wheeling-Steubenville (DMA)
# East Palestine, OH ---Greenville OH (CBSA)
# East Prairie, MO ---Sikeston MO (CBSA)
# East Prospect, PA ---Pittsburgh (DMA)
# East Quincy, CA ---Chico-Redding CA (DMA)
# East Stroudsburg, PA--NJ ---East Stroudsburg PA (CBSA)
# East Tawas, MI ---Bay City MI (CBSA)
# East Troy, WI ---Whitewater WI (CBSA)
# Eastland, TX ---Abilene TX (CBSA)
# Eastman, GA ---Tallahassee et al FL-GA (DMA)
# Easton, MD ---Baltimore
# Eaton Rapids, MI ---Lansing-East Lansing MI (CBSA)
# Eaton, CO ---Greeley CO (CBSA)
# Eaton, OH ---Monroe-El Dorado (DMA)
# Eatonton, GA ---Milledgeville GA (CBSA)
# Eatonville, WA ---Seattle/Tacoma
# Eau Claire, WI ---La Crosse-Eau Claire (DMA)
# Ebensburg, PA ---Johnstown-Altoona (DMA)
# Eden, NC ---Martinsville VA (CBSA)
# Edenton, NC ---Elizabeth City NC (CBSA)
# Edgefield, SC ---Augusta (DMA)
# Edgerton, WI ---Janesville WI (CBSA)
# Edgewood, NM ---Albuquerque
# Edinboro, PA ---Meadville PA (CBSA)
# Edna, TX ---Victoria TX (CBSA)
# Edwards, CO ---Denver-Aurora CO (CBSA)
# Effingham, IL ---Effingham IL (CBSA)
# Eielson AFB, AK ---Victoria (DMA)
# El Campo, TX ---El Campo TX (CBSA)
# El Centro--Calexico, CA ---El Centro CA (CBSA)
# El Dorado Springs, MO ---Joplin-Pittsburg (DMA)
# El Dorado, AR ---El Dorado AR (CBSA)
# El Dorado, KS ---Wichita KS (CBSA)
# El Paso de Robles (Paso Robles)--Atascadero, CA ---Hanford-Corcoran CA (CBSA)
# El Paso, IL ---Bloomington IL (CBSA)
# El Paso, TX--NM ---El Paso (Las Cruces) (DMA)
# El Reno, OK ---Oklahoma City (DMA)
# Elberton, GA ---Jefferson GA (CBSA)
# Eldon, MO ---Jefferson City MO (CBSA)
# Eldorado at Santa Fe, NM ---Albuquerque
# Eldorado, IL ---Mount Vernon IL (CBSA)
# Electra, TX ---Elk City OK (CBSA)
# Elgin, TX ---Austin (DMA)
# Elizabeth City, NC ---Elizabeth City NC (CBSA)
# Elizabethtown--Radcliff, KY ---Glasgow KY (CBSA)
# Elizabethtown, NC ---Lumberton NC (CBSA)
# Elk City, OK ---Elk City OK (CBSA)
# Elkhart, IN--MI ---Alma MI (CBSA)
# Elkhorn, WI ---Whitewater WI (CBSA)
# Elkin, NC ---North Wilkesboro NC (CBSA)
# Elkins, WV ---Elkins WV (CBSA)
# Elko New Market, MN ---Minneapolis-Saint Paul (DMA)
# Elko, NV ---Elko NV (CBSA)
# Elkton, VA ---Harrisonburg VA (CBSA)
# Ellensburg, WA ---Yakima WA (CBSA)
# Ellenville, NY ---East Stroudsburg PA (CBSA)
# Ellijay, GA ---Dalton GA (CBSA)
# Ellsworth, KS ---Wichita KS (CBSA)
# Ellsworth, ME ---Boston
# Ellsworth, WI ---Menomonie WI (CBSA)
# Ellwood City, PA ---Youngstown (DMA)
# Elmira, NY ---Sayre PA (CBSA)
# Elmwood, IL ---Canton IL (CBSA)
# Eloy, AZ ---Tucson
# Elroy, TX ---Austin (DMA)
# Elverson, PA ---Reading PA (CBSA)
# Elwood, IN ---Marion IN (CBSA)
# Ely, MN ---Duluth MN-WI (CBSA)
# Ely, NV ---Elko NV (CBSA)
# Emajagua, PR ---Caguas (Region) (DMA)
# Emerald Bay, TX ---Jacksonville TX (CBSA)
# Emmetsburg, IA ---Worthington MN (CBSA)
# Emmett, ID ---Boise City-Nampa ID (CBSA)
# Emmitsburg, MD--PA ---Gettysburg PA (CBSA)
# Emporia, KS ---Emporia KS (CBSA)
# Emporia, VA ---Roanoke Rapids NC (CBSA)
# Emporium, PA ---Bradford PA (CBSA)
# Enfield, NC ---Rocky Mount NC (CBSA)
# England, AR ---Little Rock-Pine Bluff (DMA)
# Enid, OK ---Stillwater OK (CBSA)
# Ennis, TX ---Dallas
# Enterprise, AL ---Ozark AL (CBSA)
# Ephraim, UT ---Fargo-Valley City (DMA)
# Ephrata, WA ---Wenatchee WA (CBSA)
# Epping, NH ---Boulder CO  (CBSA)
# Erie, PA ---Erie PA (CBSA)
# Erwin, TN ---Johnson City TN (CBSA)
# Escalon, CA ---Modesto CA (CBSA)
# Escanaba, MI ---Escanaba MI (CBSA)
# Espanola, NM ---Albuquerque
# Esparto, CA ---Sacramento
# Estacada, OR ---Portland OR (DMA)
# Estes Park, CO ---Fort Dodge IA  (CBSA)
# Estherville, IA ---Worthington MN (CBSA)
# Estrella, AZ ---Phoenix
# Etowah, TN ---Athens TN (CBSA)
# Eudora, KS ---Lawrence KS (CBSA)
# Eufaula, AL--GA ---Columbus GA (DMA)
# Eugene, OR ---Eugene OR (DMA)
# Eunice, LA ---Opelousas-Eunice LA (CBSA)
# Eunice, NM ---Hobbs NM (CBSA)
# Eureka, CA ---Redding CA (CBSA)
# Eureka, IL ---Peoria-Bloomington (DMA)
# Eureka, KS ---Emporia KS (CBSA)
# Eureka, MO ---Saint Louis (DMA)
# Evanston, WY ---Evanston WY (CBSA)
# Evansville, IN--KY ---Danville KY (CBSA)
# Evansville, WI ---Janesville WI (CBSA)
# Evarts, KY ---Morristown TN (CBSA)
# Everett, PA ---Johnstown-Altoona (DMA)
# Evergreen, AL ---Selma AL (CBSA)
# Evergreen, CO ---Denver-Aurora CO (CBSA)
# Everson, WA ---Washington-Arlington-Alexandria DC-VA-MD-WV (CBSA)
# Excelsior Springs, MO ---Kansas City MO-KS (CBSA)
# Fabens, TX ---El Paso TX (CBSA)
# Fair Haven, VT ---Glens Falls NY (CBSA)
# Fairbanks, AK ---Victoria (DMA)
# Fairbury, IL ---Bloomington IL (CBSA)
# Fairbury, NE ---Hastings NE (CBSA)
# Fairdale, PA ---Morgantown WV (CBSA)
# Fairfield Glade, TN ---Sevierville TN (CBSA)
# Fairfield Harbour, NC ---New Bern NC (CBSA)
# Fairfield, CA ---San Francisco
# Fairfield, IA ---Iowa City IA (CBSA)
# Fairfield, IL ---Mount Vernon IL (CBSA)
# Fairfield, TX ---Palestine TX (CBSA)
# Fairmont, MN ---New Ulm MN (CBSA)
# Fairmont, NC ---Lumberton NC (CBSA)
# Fairmont, WV ---Fairmont WV (CBSA)
# Fairmount, IN ---Marion IN (CBSA)
# Fairview, TN ---Nashville (DMA)
# Fajardo, PR ---Caguas (Region) (DMA)
# Falfurrias, TX ---Corpus Christi TX (CBSA)
# Fallon, NV ---Reno
# Falls City, NE ---Atchison KS (CBSA)
# Fargo, ND--MN ---Fargo ND-MN (CBSA)
# Faribault, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Farmersville, TX ---Dallas
# Farmerville, LA ---Monroe LA (CBSA)
# Farmington, ME ---Boulder CO  (CBSA)
# Farmington, MO ---Farmington MO (CBSA)
# Farmington, NH ---Boulder CO  (CBSA)
# Farmington, NM ---Farmington NM (CBSA)
# Farmville, NC ---Greenville NC (CBSA)
# Farmville, VA ---Kingsport-Bristol-Bristol TN-VA (CBSA)
# Fayette, AL ---Tuscaloosa AL (CBSA)
# Fayette, MO ---Moberly MO (CBSA)
# Fayetteville--Springdale--Rogers, AR--MO ---Fayetteville-Springdale-Rogers AR-MO (CBSA)
# Fayetteville, NC ---Fayetteville NC (CBSA)
# Fayetteville, TN ---Richmond-Petersburg (DMA)
# Fearrington Village, NC ---Virginia Beach-Norfolk-Newport News VA-NC (CBSA)
# Federalsburg, MD ---Baltimore
# Fellsmere, FL ---Sebastian-Vero Beach FL (CBSA)
# Fergus Falls, MN ---Alice TX  (CBSA)
# Fernandina Beach, FL ---Jacksonville
# Fernley, NV ---Reno
# Ferriday, LA ---Natchez MS-LA (CBSA)
# Filer, ID ---Twin Falls ID (CBSA)
# Fillmore, CA ---Los Angeles (DMA)
# Findlay, OH ---Findlay OH (CBSA)
# Firebaugh, CA ---Madera CA (CBSA)
# Firestone--Frederick, CO ---Fort Dodge IA  (CBSA)
# Fitzgerald, GA ---Tallahassee et al FL-GA (DMA)
# Flagstaff, AZ ---Phoenix
# Flemingsburg, KY ---Pottsville PA  (CBSA)
# Flint, MI ---Flint MI (CBSA)
# Flora, IL ---Effingham IL (CBSA)
# Florence, AL ---Florence-Muscle Shoals AL (CBSA)
# Florence, AZ ---Phoenix
# Florence, CO ---Canon City CO (CBSA)
# Florence, OR ---Eugene OR (DMA)
# Florence, SC ---Florence SC (CBSA)
# Floresville, TX ---San Antonio TX (CBSA)
# Florida--Imb_ry--Barceloneta, PR ---Arecibo (Region) (DMA)
# Floydada, TX ---Plainview TX (CBSA)
# Foley, AL ---Daphne-Fairhope AL (CBSA)
# Folkston, GA ---Brunswick GA (CBSA)
# Fond du Lac, WI ---Chicago-Naperville-Joliet IL-IN-WI (CBSA)
# Fordyce, AR ---Little Rock-Pine Bluff (DMA)
# Forest City, IA ---Boone IA (CBSA)
# Forest City, NC ---Forest City NC (CBSA)
# Forest Lake, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Forest, MS ---Jackson MS (CBSA)
# Forestville, CA ---Clearlake CA (CBSA)
# Forks, WA ---Victoria (DMA)
# Forney, TX ---Dallas
# Forrest City, AR ---Helena-West Helena AR (CBSA)
# Forsyth, GA ---Warner Robins GA (CBSA)
# Forsyth, MO ---Branson MO (CBSA)
# Fort Atkinson, WI ---Watertown-Fort Atkinson WI (CBSA)
# Fort Bragg, CA ---Clearlake CA (CBSA)
# Fort Branch, IN ---Evansville IN-KY (CBSA)
# Fort Collins, CO ---Fort Dodge IA  (CBSA)
# Fort Defiance, AZ--NM ---Gallup NM (CBSA)
# Fort Dodge, IA ---Boone IA (CBSA)
# Fort Irwin, CA ---Modesto CA (CBSA)
# Fort Leonard Wood, MO ---Saint Joseph (DMA)
# Fort Lupton, CO ---Greeley CO (CBSA)
# Fort Madison, IA--IL ---Macomb IL (CBSA)
# Fort Meade, FL ---Wauchula FL (CBSA)
# Fort Morgan, CO ---Canon City CO (CBSA)
# Fort Payne, AL ---Summerville GA (CBSA)
# Fort Plain, NY ---Albany-Schenectady-Troy (DMA)
# Fort Polk, LA ---Fort Smith AR-OK  (CBSA)
# Fort Scott, KS ---Joplin-Pittsburg (DMA)
# Fort Smith, AR--OK ---El Dorado AR (CBSA)
# Fort Stockton, TX ---Hobbs NM (CBSA)
# Fort Valley, GA ---Warner Robins GA (CBSA)
# Fort Walton Beach--Navarre--Wright, FL ---Crestview-Fort Walton Beach-Destin FL (CBSA)
# Fort Wayne, IN ---Richmond IN (CBSA)
# Fortuna, CA ---Redding CA (CBSA)
# Fostoria, OH ---Tiffin OH (CBSA)
# Four Corners, FL ---Tampa-St. Petersburg-Clearwater FL (CBSA)
# Four Corners, MT ---Butte-Bozeman (DMA)
# Fowlerville, MI ---Lansing-East Lansing MI (CBSA)
# Frankenmuth, MI ---Saginaw-Saginaw Township North MI (CBSA)
# Frankfort, IN ---Lafayette IN (DMA)
# Frankfort, KY ---Frankfort KY (CBSA)
# Franklin (Venango County), PA ---Okeechobee FL  (CBSA)
# Franklin--Highland Lake, NJ ---New York (Northern New Jersey)
# Franklin, KY ---Nashville (DMA)
# Franklin, LA ---Morgan City LA (CBSA)
# Franklin, NC ---Brevard NC (CBSA)
# Franklin, NH ---Boulder CO  (CBSA)
# Franklin, VA ---Norfolk-Portsmouth-Newport News (DMA)
# Franklinton, LA ---Bogalusa LA (CBSA)
# Fraser, CO ---Fort Dodge IA  (CBSA)
# Frazier Park, CA ---Bakersfield CA (CBSA)
# Frederick, MD ---Gettysburg PA (CBSA)
# Frederick, OK ---Elk City OK (CBSA)
# Fredericksburg, TX ---Fredericksburg TX (CBSA)
# Fredericksburg, VA ---Washington et al DC-MD (DMA)
# Fredericktown, MO ---Farmington MO (CBSA)
# Freeport, IL ---Rockford IL (CBSA)
# Fremont, MI ---Muskegon-Norton Shores MI (CBSA)
# Fremont, NE ---Fremont NE (CBSA)
# Fremont, OH ---Fremont OH (CBSA)
# Fresno, CA ---Fresno CA (CBSA)
# Friona, TX ---Ames IA  (CBSA)
# Fritch, TX ---Ames IA  (CBSA)
# Front Royal, VA ---Winston-Salem NC  (CBSA)
# Frostproof, FL ---Sebring FL (CBSA)
# Fulton, KY--TN ---Union City TN-KY (CBSA)
# Fulton, MO ---Mexico MO (CBSA)
# Fulton, MS ---Tupelo MS (CBSA)
# Gadsden, AL ---Gadsden AL (CBSA)
# Gaffney, SC ---Shelbyville TN  (CBSA)
# Gainesville, FL ---Gainesville
# Gainesville, GA ---Gainesville GA (CBSA)
# Gainesville, TX ---Dallas-Fort Worth-Arlington TX (CBSA)
# Galax, VA ---North Wilkesboro NC (CBSA)
# Galena, IL ---Dubuque IA (CBSA)
# Galena, KS--MO ---Joplin MO (CBSA)
# Galesburg, IL ---Galesburg IL (CBSA)
# Galion, OH ---Mansfield OH (CBSA)
# Galliano--Larose--Cut Off, LA ---New Orleans-Metairie-Kenner LA (CBSA)
# Gallup, NM ---Gallup NM (CBSA)
# Galt, CA ---Sacramento
# Galveston, TX ---Houston
# Garden City, KS ---Ames IA  (CBSA)
# Gardnerville Ranchos, NV ---Reno
# Garner, IA ---Boone IA (CBSA)
# Garnett, KS ---Lawrence KS (CBSA)
# Garrettsville, OH ---Cleveland-Akron (Canton) (DMA)
# Gastonia, NC--SC ---Charlotte (DMA)
# Gatesville, TX ---Killeen-Temple-Fort Hood TX (CBSA)
# Gautier, MS ---Guymon OK  (CBSA)
# Gaylord, MI ---Traverse City MI (CBSA)
# Geneseo, IL ---Davenport-Rock Island-Moline (DMA)
# Geneseo, NY ---Rochester NY (CBSA)
# Geneva, AL ---Ozark AL (CBSA)
# Geneva, NY ---Rochester NY (CBSA)
# Geneva, OH ---Ashtabula OH (CBSA)
# Genoa, IL ---Rockford IL (CBSA)
# Genoa, OH ---Toledo OH (CBSA)
# Georgetown, DE ---Wilmington (DMA)
# Georgetown, KY ---Lincoln IL  (CBSA)
# Georgetown, OH ---Cincinnati (DMA)
# Georgetown, SC ---Florence SC (CBSA)
# Gibson City, IL ---Champaign-Urbana IL (CBSA)
# Giddings, TX ---Brenham TX (CBSA)
# Gillespie, IL ---Saint Louis (DMA)
# Gillette, WY ---Gillette WY (CBSA)
# Gilman, IL ---Champaign-Urbana IL (CBSA)
# Gilmer, TX ---Longview TX (CBSA)
# Gilroy--Morgan Hill, CA ---Modesto CA (CBSA)
# Girard, KS ---Joplin-Pittsburg (DMA)
# Gladwin, MI ---Midland MI (CBSA)
# Glasgow, KY ---Glasgow KY (CBSA)
# Glasgow, MT ---Glendive MT (DMA)
# Glencoe, MN ---Hutchinson MN (CBSA)
# Glendive, MT ---Glendive MT (DMA)
# Glennville, GA ---Hinesville-Fort Stewart GA (CBSA)
# Glens Falls, NY ---Glens Falls NY (CBSA)
# Glenville, WV ---Hagerstown-Martinsburg MD-WV (CBSA)
# Glenwood Springs, CO ---Canon City CO (CBSA)
# Glenwood, IA ---Ontario OR-ID  (CBSA)
# Glenwood, MD ---Washington et al DC-MD (DMA)
# Globe, AZ ---Tucson
# Gloucester Courthouse, VA ---Norfolk-Portsmouth-Newport News (DMA)
# Glouster, OH ---Athens OH (CBSA)
# Gloversville, NY ---Albany-Schenectady-Troy (DMA)
# Gold Beach, OR ---Eugene OR (DMA)
# Golden Beach, MD ---Washington et al DC-MD (DMA)
# Golden Gate Estates, FL ---Naples-Marco Island FL (CBSA)
# Goldendale, WA ---Yakima WA (CBSA)
# ...
# Terra Bella, CA ---Visalia-Porterville CA (CBSA)
# Terre Haute, IN ---Terre Haute (DMA)
# Terrell, TX ---Dallas
# Texarkana--Texarkana, TX--AR ---Marshalltown IA  (CBSA)
# Texas City, TX ---Brownsville-Harlingen TX (CBSA)
# Thayer, MO--AR ---West Plains MO (CBSA)
# The Dalles, OR--WA ---Yakima WA (CBSA)
# Thermopolis, WY ---Riverton WY (CBSA)
# Thief River Falls, MN ---Fargo ND-MN (CBSA)
# Thomaston, GA ---LaGrange GA (CBSA)
# Thomasville, AL ---Montgomery-Selma (DMA)
# Thomasville, GA ---Tallahassee FL (CBSA)
# Thomson, GA ---Augusta (DMA)
# Thousand Oaks, CA ---Hanford-Corcoran CA (CBSA)
# Three Rivers, MI ---Elkhart-Goshen IN (CBSA)
# Thurmont, MD ---Gettysburg PA (CBSA)
# Ticonderoga, NY ---Glens Falls NY (CBSA)
# Tiffin, OH ---Tiffin OH (CBSA)
# Tifton, GA ---Tallahassee et al FL-GA (DMA)
# Tillamook, OR ---Salem OR (CBSA)
# Tipton, CA ---Hanford-Corcoran CA (CBSA)
# Tipton, IA ---Iowa City IA (CBSA)
# Tipton, IN ---Kokomo IN (CBSA)
# Tipton, MO ---Jefferson City MO (CBSA)
# Titusville, FL ---Pampa TX  (CBSA)
# Titusville, PA ---Okeechobee FL  (CBSA)
# Toccoa, GA ---Jefferson GA (CBSA)
# Toledo, OH--MI ---Toledo OH (CBSA)
# Toledo, OR ---Salem OR (CBSA)
# Tomah, WI ---Wisconsin Rapids-Marshfield WI Micro (CBSA)
# Tomahawk, WI ---Wausau-Rhinelander (DMA)
# Tonganoxie, KS ---Lawrence KS (CBSA)
# Tonkawa, OK ---Stillwater OK (CBSA)
# Tooele, UT ---Fargo-Valley City (DMA)
# Topeka, KS ---Topeka (DMA)
# Toppenish, WA ---Yakima WA (CBSA)
# Tornillo, TX ---El Paso TX (CBSA)
# Torrington, CT ---Hartford-West Hartford-East Hartford CT (CBSA)
# Torrington, WY ---Scottsbluff NE (CBSA)
# Towanda, PA ---Sayre PA (CBSA)
# Tracy, CA ---Modesto CA (CBSA)
# Traverse City, MI ---Traverse City MI (CBSA)
# Treasure Lake, PA ---Wilkes Barre-Scranton (DMA)
# Tremonton, UT ---Salt Lake City (DMA)
# Trenton, FL ---Gainesville
# Trenton, GA ---Chattanooga (DMA)
# Trenton, IL ---Saint Louis (DMA)
# Trenton, MO ---Kirksville MO (CBSA)
# Trenton, NJ ---Allentown-Bethlehem-Easton PA-NJ (CBSA)
# Trenton, TN ---Jackson TN (DMA)
# Tri-City--Myrtle Creek, OR ---Eugene OR (DMA)
# Trinidad, CO ---Pueblo CO (CBSA)
# Trinity, TX ---Huntsville TX (CBSA)
# Troy, AL ---Troy AL (CBSA)
# Troy, MO ---Hannibal MO (CBSA)
# Troy, NC ---Rockingham NC (CBSA)
# Truckee, CA ---Reno
# Trumann, AR ---Jonesboro AR (CBSA)
# Truth or Consequences, NM ---Las Cruces NM (CBSA)
# Tuba City, AZ ---Gallup NM (CBSA)
# Tucson, AZ ---Tucson
# Tucumcari, NM ---Ames IA  (CBSA)
# Tularosa, NM ---Alamogordo NM (CBSA)
# Tulia, TX ---Plainview TX (CBSA)
# Tullahoma, TN ---Richmond-Petersburg (DMA)
# Tulsa, OK ---Tulsa OK (CBSA)
# Tunica, MS ---Helena-West Helena AR (CBSA)
# Tunkhannock, PA ---Wilkes Barre-Scranton (DMA)
# Tupelo, MS ---Tupelo MS (CBSA)
# Tupper Lake, NY ---Plattsburgh NY (CBSA)
# Turlock, CA ---Modesto CA (CBSA)
# Tuscaloosa, AL ---Tuscaloosa AL (CBSA)
# Tuscola, IL ---Champaign-Urbana IL (CBSA)
# Tuskegee, AL ---Auburn-Opelika AL (CBSA)
# Tuttle, OK ---Oklahoma City (DMA)
# Twentynine Palms Base, CA ---El Centro CA (CBSA)
# Twentynine Palms, CA ---Los Angeles (DMA)
# Twin Falls, ID ---Twin Falls ID (CBSA)
# Twin Lakes, VA ---Richmond VA (CBSA)
# Twin Rivers--Hightstown, NJ ---Allentown-Bethlehem-Easton PA-NJ (CBSA)
# Two Harbors, MN ---Duluth MN-WI (CBSA)
# Tybee Island, GA ---Hilton Head Island-Beaufort SC (CBSA)
# Tyler, TX ---Jacksonville TX (CBSA)
# Tyrone, PA ---Amarillo TX  (CBSA)
# Ukiah, CA ---Clearlake CA (CBSA)
# Ulysses, KS ---Ames IA  (CBSA)
# Unadilla, GA ---Warner Robins GA (CBSA)
# Union City, IN--OH ---Weirton-Steubenville WV-OH (CBSA)
# Union City, PA ---Erie PA (CBSA)
# Union City, TN ---Union City TN-KY (CBSA)
# Union Grove, WI ---Milwaukee-Waukesha-West Allis WI (CBSA)
# Union Springs, AL ---Troy AL (CBSA)
# Union, MO ---Saint Louis (DMA)
# Union, SC ---Shelbyville TN  (CBSA)
# Uniontown--Connellsville, PA ---Somerset PA (CBSA)
# Upland, IN ---Marion IN (CBSA)
# Upper Greenwood Lake, NJ ---New York (Northern New Jersey)
# Upper Sandusky, OH ---Sandusky OH (CBSA)
# Urban Honolulu, HI ---San Francisco
# Urbana, OH ---Urbana OH (CBSA)
# Utica, NY ---Syracuse NY (CBSA)
# Uvalde, TX ---San Antonio TX (CBSA)
# Vacaville, CA ---Sacramento
# Vado, NM ---Las Cruces NM (CBSA)
# Vail, AZ ---Tucson
# Vail, CO ---Denver-Aurora CO (CBSA)
# Valatie, NY ---Albany-Schenectady-Troy (DMA)
# Valdosta, GA ---Lake City FL (CBSA)
# Valentine, NE ---Pierre SD (CBSA)
# Vallejo, CA ---San Francisco
# Valley City, ND ---Fargo ND-MN (CBSA)
# Valley--Lanett, AL--GA ---LaGrange GA (CBSA)
# Van Wert, OH ---Van Wert OH (CBSA)
# Van, TX ---Athens-Clarke County GA  (CBSA)
# Vandalia, IL ---Centralia IL (CBSA)
# Vandalia, MO ---Hannibal MO (CBSA)
# Vandenberg AFB, CA ---Bakersfield CA (CBSA)
# Vassar, MI ---Flint MI (CBSA)
# Veneta, OR ---Eugene OR (DMA)
# Venus, TX ---Dallas-Fort Worth-Arlington TX (CBSA)
# Vergennes, VT ---Plattsburgh NY (CBSA)
# Vermillion, SD ---Vernal UT  (CBSA)
# Vernal, UT ---Rock Springs WY (CBSA)
# Vernon, TX ---Elk City OK (CBSA)
# Versailles, KY ---Frankfort KY (CBSA)
# Versailles, OH ---Greenville OH (CBSA)
# Vicksburg, MS--LA ---Vicksburg MS (CBSA)
# Victoria, TX ---Victoria TX (CBSA)
# Victorville--Hesperia, CA ---Riverside-San Bernardino-Ontario CA (CBSA)
# Vidalia, GA ---Tallahassee et al FL-GA (DMA)
# Vienna, GA ---Warner Robins GA (CBSA)
# Vieques (Vieques Municipio), PR ---Caguas (Region) (DMA)
# Village of Four Seasons, MO ---Lebanon MO (CBSA)
# Village of Oak Creek (Big Park), AZ ---Phoenix
# Villas, NJ ---Wilmington (DMA)
# Ville Platte, LA ---Opelousas-Eunice LA (CBSA)
# Vincennes, IN ---Vincennes IN (CBSA)
# Vineland, NJ ---Philadelphia-Camden-Wilmington PA-NJ-DE-MD (CBSA)
# Vineyard Haven, MA ---Providence-New Bedford (DMA)
# Vinita, OK ---Joplin MO (CBSA)
# Vinton, IA ---Cedar Rapids IA (CBSA)
# Vinton, LA ---Lake Charles (DMA)
# Virden, IL ---Taylorville IL (CBSA)
# Virginia Beach, VA ---Norfolk-Portsmouth-Newport News (DMA)
# Virginia, MN ---Duluth MN-WI (CBSA)
# Viroqua, WI ---Platteville WI (CBSA)
# Visalia, CA ---Fresno-Visalia (DMA)
# Vistancia, AZ ---Phoenix
# Vivian, LA ---Shreveport-Bossier City LA (CBSA)
# Wabash, IN ---Wabash IN (CBSA)
# Waco, TX ---Waco-Temple-Bryan (DMA)
# Waconia, MN ---Minneapolis-Saint Paul (DMA)
# Wadena, MN ---Alice TX  (CBSA)
# Wadesboro, NC ---Rockingham NC (CBSA)
# Wagoner, OK ---Muskogee OK (CBSA)
# Wahoo, NE ---Fremont NE (CBSA)
# Wahpeton, ND--MN ---Fargo ND-MN (CBSA)
# Waikoloa Village, HI ---San Francisco
# Waimea (Hawaii County), HI ---San Francisco
# Walden, NY ---New York (Northern New Jersey)
# Waldorf, MD ---Washington et al DC-MD (DMA)
# Waldport, OR ---Eugene OR (DMA)
# Waldron, AR ---Ft. Smith
# Walkerton, IN ---Plymouth IN (CBSA)
# Walla Walla, WA--OR ---Yakima-Pasco-Richland-Kennewick (DMA)
# Wallace, NC ---Wilmington NC (CBSA)
# Walnut Ridge, AR ---Jonesboro AR (CBSA)
# Walsenburg, CO ---Colorado Springs-Pueblo (DMA)
# Walterboro, SC ---Hilton Head Island-Beaufort SC (CBSA)
# Walters, OK ---Oklahoma City (DMA)
# Walton, NY ---Wilkes Barre-Scranton (DMA)
# Walworth, NY ---Rochester NY (CBSA)
# Walworth, WI ---Whitewater WI (CBSA)
# Wamego, KS ---Topeka (DMA)
# Wapakoneta, OH ---Wapakoneta OH (CBSA)
# Wapato, WA ---Yakima WA (CBSA)
# Warden, WA ---Yakima-Pasco-Richland-Kennewick (DMA)
# Ware, MA ---Springfield MA (CBSA)
# Warner Robins, GA ---Warner Robins GA (CBSA)
# Warren, AR ---Little Rock-Pine Bluff (DMA)
# Warren, PA ---Warren PA (CBSA)
# Warrensburg, MO ---Warrensburg MO (CBSA)
# Warrensburg, NY ---Glens Falls NY (CBSA)
# Warrenton, MO ---Mexico MO (CBSA)
# Warsaw, IN ---Warsaw IN (CBSA)
# Warsaw, MO ---Warrensburg MO (CBSA)
# Warsaw, NC ---Goldsboro NC (CBSA)
# Warsaw, NY ---Batavia NY (CBSA)
# Warwick, NY ---New York (Northern New Jersey)
# Wasco, CA ---Bakersfield CA (CBSA)
# Waseca, MN ---Minneapolis-Saint Paul (DMA)
# Washington Court House, OH ---Washington Court House OH Micro (CBSA)
# Washington, DC--VA--MD ---Washington et al DC-MD (DMA)
# Washington, GA ---Augusta (DMA)
# Washington, IA ---Iowa City IA (CBSA)
# Washington, IN ---Washington IN (CBSA)
# Washington, MO ---Saint Louis (DMA)
# Washington, NC ---Washington NC (CBSA)
# Washington, NJ ---East Stroudsburg PA (CBSA)
# Washoe Valley, NV ---Las Vegas NM  (CBSA)
# Watchtower, NY ---Syracuse NY (CBSA)
# Water Valley, MS ---Greenwood MS (CBSA)
# Waterbury, CT ---New Haven-Milford CT (CBSA)
# Waterbury, VT ---Plattsburgh NY (CBSA)
# Waterford, CA ---Modesto CA (CBSA)
# Waterloo, IA ---Cedar Rapids IA (CBSA)
# Waterloo, IL ---Saint Louis (DMA)
# Waterloo, WI ---Watertown-Fort Atkinson WI (CBSA)
# Watertown, MN ---Hutchinson MN (CBSA)
# Watertown, NY ---Watertown-Fort Drum NY (CBSA)
# Watertown, SD ---Watertown SD (CBSA)
# Watertown, WI ---Watertown-Fort Atkinson WI (CBSA)
# Waterville, ME ---Boulder CO  (CBSA)
# Watkins Glen, NY ---Albany-Schenectady-Troy (DMA)
# Watonga, OK ---Oklahoma City (DMA)
# Watseka, IL ---Danville IL (CBSA)
# Watsonville, CA ---Modesto CA (CBSA)
# Wauchula, FL ---Wauchula FL (CBSA)
# Waukon, IA ---Dubuque IA (CBSA)
# Waupaca, WI ---Stevens Point WI (CBSA)
# Waupun, WI ---Chicago-Naperville-Joliet IL-IN-WI (CBSA)
# Wausau, WI ---Wausau WI (CBSA)
# Wauseon, OH ---Adrian MI (CBSA)
# Wautoma, WI ---Stevens Point WI (CBSA)
# Waverly City, OH ---Chillicothe OH (CBSA)
# Waverly, IA ---Cedar Rapids IA (CBSA)
# Waverly, NE ---Fremont NE (CBSA)
# Waverly, TN ---Paris TN (CBSA)
# Waycross, GA ---Brunswick GA (CBSA)
# Wayland, MI ---Grand Rapids-Wyoming MI (CBSA)
# Wayne, NE ---Norfolk NE (CBSA)
# Waynesboro, GA ---Augusta (DMA)
# Waynesboro, MS ---Laurel MS (CBSA)
# Waynesboro, PA--MD ---Gettysburg PA (CBSA)
# Waynesburg, PA ---Morgantown WV (CBSA)
# Weatherford, OK ---Elk City OK (CBSA)
# Weatherford, TX ---Dallas-Fort Worth (DMA)
# Webster City, IA ---Boone IA (CBSA)
# Wedgefield, FL ---Pampa TX  (CBSA)
# Weedsport, NY ---Syracuse NY (CBSA)
# Weirton--Steubenville, WV--OH--PA ---New York-Northern New Jersey-Long Island NY-NJ-PA (CBSA)
# Weiser, ID--OR ---Boise City-Nampa ID (CBSA)
# Welch, WV ---Bluefield WV-VA (CBSA)
# Wellington, CO ---Fort Dodge IA  (CBSA)
# Wellington, KS ---Wichita KS (CBSA)
# Wellington, OH ---Mansfield OH (CBSA)
# Wellsville, NY ---Bradford PA (CBSA)
# Welsh, LA ---Lake Charles (DMA)
# Wenatchee, WA ---Wenatchee WA (CBSA)
# Wendell--Zebulon, NC ---Raleigh-Durham (Fayetteville) (DMA)
# Wendell, ID ---Twin Falls ID (CBSA)
# West Bend, WI ---Milwaukee-Waukesha-West Allis WI (CBSA)
# West Columbia, TX ---El Campo TX (CBSA)
# West Frankfort, IL ---Chicago
# West Jefferson, OH ---Ashtabula OH (CBSA)
# West Lafayette, OH ---Wapakoneta OH (CBSA)
# West Liberty, IA ---Des Moines
# West Plains, MO ---West Plains MO (CBSA)
# West Point, MS ---Starkville MS (CBSA)
# West Point, NE ---Fremont NE (CBSA)
# West Point, NY ---New York (Northern New Jersey)
# West Point, VA ---Richmond VA (CBSA)
# West Tawakoni, TX ---Sulphur Springs TX (CBSA)
# West Union, OH ---Dayton OH (CBSA)
# West Wendover, NV--UT ---Elko NV (CBSA)
# West, TX ---Waco-Temple-Bryan (DMA)
# Westernport, MD--WV ---Cumberland MD-WV (CBSA)
# Westfield, NY ---Erie PA (CBSA)
# Westminster--Eldersburg, MD ---Baltimore
# Weston Lakes, TX ---Houston
# Weston, WV ---Clarksburg WV (CBSA)
# Westville, IN ---Plymouth IN (CBSA)
# Wetumpka, AL ---Montgomery AL (CBSA)
# Wewoka, OK ---Shawnee OK (CBSA)
# Weyers Cave, VA ---Harrisonburg VA (CBSA)
# Wharton, TX ---El Campo TX (CBSA)
# Wheatland, CA ---Sacramento
# Wheatland, WY ---Laramie WY (CBSA)
# Wheeling, WV--OH ---Wheeling WV-OH (CBSA)
# Whispering Pines, NC ---Sanford NC (CBSA)
# White Hall, IL ---Jacksonville NC  (CBSA)
# White Pine, TN ---Morristown TN (CBSA)
# White Rock, NM ---Albuquerque
# White Sulphur Springs, WV ---Charleston-Huntington (DMA)
# Whitefish, MT ---Kalispell MT (CBSA)
# Whitehall, MI ---Muskegon-Norton Shores MI (CBSA)
# Whiteman AFB, MO ---Warrensburg MO (CBSA)
# Whiteriver, AZ ---Tucson
# Whitesboro, TX ---Dallas
# Whiteville, NC ---Lumberton NC (CBSA)
# Whitewater, WI ---Whitewater WI (CBSA)
# Wichita Falls, TX ---Dallas-Fort Worth (DMA)
# Wichita, KS ---Wichita KS (CBSA)
# Wickenburg, AZ ---Phoenix
# Wiggins, MS ---Guymon OK  (CBSA)
# Wilburton, OK ---Muskogee OK (CBSA)
# Willard, MO ---Springfield MO (CBSA)
# Willard, OH ---Mansfield OH (CBSA)
# Willcox, AZ ---Tucson
# Williams, AZ ---Phoenix
# Williams, CA ---Clearlake CA (CBSA)
# Williamsburg, IA ---Cedar Rapids IA (CBSA)
# Williamsburg, KY ---Somerset KY (CBSA)
# Williamsburg, VA ---Norfolk-Portsmouth-Newport News (DMA)
# Williamson, WV--KY ---Charleston-Huntington (DMA)
# Williamsport, PA ---Williamsport PA (CBSA)
# Williamston, MI ---Lansing-East Lansing MI (CBSA)
# Williamston, NC ---Greenville-New Bern-Washington (DMA)
# Williamstown, KY ---Cincinnati (DMA)
# Williamstown, PA ---Lebanon PA (CBSA)
# Willimantic, CT ---Norwich-New London CT (CBSA)
# Williston, FL ---Gainesville
# Williston, ND ---Glendive MT (DMA)
# Willits, CA ---Clearlake CA (CBSA)
# Willmar, MN ---Willmar MN (CBSA)
# Willows, CA ---Chico-Redding CA (DMA)
# Wills Point, TX ---Sulphur Springs TX (CBSA)
# Wilmington, NC ---Wilmington NC (CBSA)
# Wilmington, OH ---Washington Court House OH Micro (CBSA)
# Wilmore, KY ---Lincoln IL  (CBSA)
# Wilson, NC ---Wilson NC (CBSA)
# Wilton, IA ---Davenport-Rock Island-Moline (DMA)
# Winamac, IN ---Plymouth IN (CBSA)
# Winchester, IN ---Richmond IN (CBSA)
# Winchester, KY ---Lincoln IL  (CBSA)
# Winchester, TN ---Richmond-Petersburg (DMA)
# Winchester, VA ---Winston-Salem NC  (CBSA)
# Winder, GA ---Jefferson GA (CBSA)
# Windom, MN ---Worthington MN (CBSA)
# Window Rock, AZ--NM ---Gallup NM (CBSA)
# Windsor, MO ---Warrensburg MO (CBSA)
# Windsor, NC ---Greenville-New Bern-Washington (DMA)
# Windsor, VT--NH ---Boulder CO  (CBSA)
# Winfield, KS ---Wichita KS (CBSA)
# Winneconne, WI ---Oskaloosa IA  (CBSA)
# Winnemucca, NV ---Elko NV (CBSA)
# Winner, SD ---Pierre SD (CBSA)
# Winnfield, LA ---Natchitoches LA (CBSA)
# Winnie, TX ---Beaumont-Port Arthur (DMA)
# Winnsboro, LA ---Monroe LA (CBSA)
# Winnsboro, SC ---Columbia SC (DMA)
# Winnsboro, TX ---Sulphur Springs TX (CBSA)
# Winona, MN ---La Crosse-Eau Claire (DMA)
# Winona, MS ---Grenada MS (CBSA)
# Winslow, AZ ---Gallup NM (CBSA)
# Winston-Salem, NC ---Hickory-Lenoir-Morganton NC (CBSA)
# Winter Haven, FL ---Orlando-Kissimmee FL (CBSA)
# Winters, CA ---Sacramento
# Winters, TX ---Abilene TX (CBSA)
# Winterset, IA ---Des Moines
# Wisconsin Rapids, WI ---Wisconsin Rapids-Marshfield WI Micro (CBSA)
# Wolf Point, MT ---Glendive MT (DMA)
# Wonder Lake, IL ---Chicago
# Woodburn, OR ---Salem OR (CBSA)
# Woodbury, TN ---McMinnville TN (CBSA)
# Woodcreek, TX ---Austin (DMA)
# Woodlake, CA ---Fresno-Visalia (DMA)
# Woodland Park, CO ---Colorado Springs CO (CBSA)
# Woodland, CA ---Sacramento
# Woodland, WA ---Portland OR (DMA)
# Woodruff, SC ---Forest City NC (CBSA)
# Woodstock, AL ---Birmingham-Hoover AL (CBSA)
# Woodstock, IL ---Whitewater WI (CBSA)
# Woodstock, VA ---Winston-Salem NC  (CBSA)
# Woodstown, NJ ---Wilmington (DMA)
# Woodville, FL ---Tallahassee FL (CBSA)
# Woodville, TX ---Nacogdoches TX (CBSA)
# Woodward, OK ---Elk City OK (CBSA)
# Wooster, OH ---Cleveland-Akron (Canton) (DMA)
# Worcester, MA--CT ---Providence-New Bedford-Fall River RI-MA (CBSA)
# Worland, WY ---Riverton WY (CBSA)
# World Golf Village, FL ---Palatka FL (CBSA)
# Worthington, MN ---Worthington MN (CBSA)
# Wright City, MO ---Saint Louis (DMA)
# Wrightstown, WI ---Green Bay WI (CBSA)
# Wrightsville, GA ---Tallahassee et al FL-GA (DMA)
# Wrightwood, CA ---Riverside-San Bernardino-Ontario CA (CBSA)
# Wurtsboro, NY ---East Stroudsburg PA (CBSA)
# Wynne, AR ---Jonesboro AR (CBSA)
# Wytheville, VA ---Bluefield WV-VA (CBSA)
# Yadkinville, NC ---Greensboro-High Point-Winston-Salem (DMA)
# Yakima, WA ---Yakima WA (CBSA)
# Yankton, SD ---Yankton SD (CBSA)
# Yauco, PR ---Ponce (Region) (DMA)
# Yazoo City, MS ---Jackson MS (CBSA)
# Yellow Springs, OH ---Springfield OH (CBSA)
# Yelm, WA ---Seattle/Tacoma
# Yerington, NV ---Reno
# Yoakum, TX ---Victoria TX (CBSA)
# York, NE ---Columbus NE (CBSA)
# York, PA ---Harrisburg-Carlisle PA (CBSA)
# York, SC ---Shelbyville TN  (CBSA)
# Yorkville, GA ---Cedartown GA (CBSA)
# Youngstown, OH--PA ---Youngstown (DMA)
# Youngsville, PA ---Warren PA (CBSA)
# Yountville, CA ---Clearlake CA (CBSA)
# Yreka, CA ---Redding CA (CBSA)
# Yuba City, CA ---Sacramento
# Yucca Valley, CA ---Riverside-San Bernardino-Ontario CA (CBSA)
# Yulee, FL ---Jacksonville
# Yuma, AZ--CA ---Yuma AZ (CBSA)
# Yuma, CO ---Cheyenne-Scottsbluff (DMA)
# Zanesville, OH ---Zanesville (DMA)
# Zapata--Medina, TX ---Fredericksburg TX (CBSA)
# Zephyrhills, FL ---Tampa
# Zimmerman, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Zumbrota, MN ---Minneapolis-St. Paul-Bloomington MN-WI (CBSA)
# Zuni Pueblo, NM ---Gallup NM (CBSA)

# %%
import csv
with open('../data/urban_rates.csv', 'wb') as csvfile:
    csvwriter = csv.writer(csvfile, quoting=csv.QUOTE_NONNUMERIC)
    for row_index, row in urban.iterrows():
        csvwriter.writerow([row["UANUM"], row["UANAME"], ads.values[i[row_index], 1]])
